# %% [markdown]
# # Model recovery attack: `credit-card`

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import mra
from mra import *
import models
from models import *

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
def make_dataset(X, Y, f):
    x = tf.data.Dataset.from_tensor_slices(X)
    y = tf.data.Dataset.from_tensor_slices(Y)
    x = x.map(f)
    xy = tf.data.Dataset.zip((x, y))
    xy = xy.shuffle(10000)
    return xy

df = pd.read_excel('../datasets/credit-card.xls', header=1, index_col=0).sample(frac=1)
x = df.drop(columns=["default payment next month"]).to_numpy()
x = (x - np.min(x, axis=0))/(np.max(x, axis=0) - np.min(x, axis=0))
y = df["default payment next month"].to_numpy().reshape((len(x), 1)).astype("float32")
train_ds = make_dataset(x, y, lambda t: t)
# Out:
# 2022-03-30 03:32:56.881825: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-30 03:32:56.881918: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: xgpd0
# 2022-03-30 03:32:56.881937: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: xgpd0
# 2022-03-30 03:32:56.882185: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.103.1
# 2022-03-30 03:32:56.882245: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.103.1
# 2022-03-30 03:32:56.882261: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.103.1
# 2022-03-30 03:32:56.883948: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
main = {}

for split in [2,3,4]:
    print("split = {}".format(split))
    main[split] = mra(train_ds)
    make_f, make_g, make_generator = models.make_mlp(
        attr_num=23,
        class_num=2,
        split=split,
        fg_units=64,
        fg_act="relu",
        generator_units=[512,256,128,64]
    )
    main[split].train(
        make_f,
        make_g,
        loss_fn=tf.keras.losses.BinaryCrossentropy(),
        batch_size=32,
        epoch=5,
        lr=0.001,
        verbose=True, log_every=1000
    )
# Out:
# split = 2
# Iteration 1000: Training loss: 0.4665
# Iteration 2000: Training loss: 0.4448
# Iteration 3000: Training loss: 0.4394
# Iteration 4000: Training loss: 0.4364
# split = 3
# Iteration 1000: Training loss: 0.4610
# Iteration 2000: Training loss: 0.4417
# Iteration 3000: Training loss: 0.4403
# Iteration 4000: Training loss: 0.4378
# split = 4
# Iteration 1000: Training loss: 0.4649
# Iteration 2000: Training loss: 0.4426
# Iteration 3000: Training loss: 0.4407
# Iteration 4000: Training loss: 0.4353

# %%
log_attack = {}
for split in [4,3,2]:
    print("split level = {}".format(split))
    log_attack[split] = main[split].attack(
        attack_iter=100,
        make_generator=make_generator,
        input_noise="normal",
        input_z=True,
        model_leak=True,
        lr_x=0.0001,
        lr_f=0.00001,
        epoch=50,
        iter_x=40,
        iter_f=1,
        verbose=True, log_every=1
    )
# Out:
# split level = 4
# Iteration 0001: RG-uniform: 0.2246, RG-normal: 0.2148, reconstruction validation: 0.0482
# Iteration 0002: RG-uniform: 0.2355, RG-normal: 0.2171, reconstruction validation: 0.0476
# Iteration 0003: RG-uniform: 0.2250, RG-normal: 0.2247, reconstruction validation: 0.0403
# Iteration 0004: RG-uniform: 0.2176, RG-normal: 0.2124, reconstruction validation: 0.0439
# Iteration 0005: RG-uniform: 0.2296, RG-normal: 0.1970, reconstruction validation: 0.0369
# Iteration 0006: RG-uniform: 0.2377, RG-normal: 0.2068, reconstruction validation: 0.0382
# Iteration 0007: RG-uniform: 0.2396, RG-normal: 0.2064, reconstruction validation: 0.0407
# Iteration 0008: RG-uniform: 0.2310, RG-normal: 0.2018, reconstruction validation: 0.0391
# Iteration 0009: RG-uniform: 0.2200, RG-normal: 0.2010, reconstruction validation: 0.0331
# Iteration 0010: RG-uniform: 0.2257, RG-normal: 0.1983, reconstruction validation: 0.0375
# Iteration 0011: RG-uniform: 0.2466, RG-normal: 0.2038, reconstruction validation: 0.0321
# Iteration 0012: RG-uniform: 0.2362, RG-normal: 0.2107, reconstruction validation: 0.0307
# Iteration 0013: RG-uniform: 0.2414, RG-normal: 0.2053, reconstruction validation: 0.0349
# Iteration 0014: RG-uniform: 0.2377, RG-normal: 0.2142, reconstruction validation: 0.0310
# Iteration 0015: RG-uniform: 0.2273, RG-normal: 0.2205, reconstruction validation: 0.0375
# Iteration 0016: RG-uniform: 0.2436, RG-normal: 0.2006, reconstruction validation: 0.0298
# Iteration 0017: RG-uniform: 0.2316, RG-normal: 0.2164, reconstruction validation: 0.0341
# Iteration 0018: RG-uniform: 0.2244, RG-normal: 0.2056, reconstruction validation: 0.0406
# Iteration 0019: RG-uniform: 0.2408, RG-normal: 0.2093, reconstruction validation: 0.0328
# Iteration 0020: RG-uniform: 0.2264, RG-normal: 0.2132, reconstruction validation: 0.0296
# Iteration 0021: RG-uniform: 0.2173, RG-normal: 0.2018, reconstruction validation: 0.0320
# Iteration 0022: RG-uniform: 0.2312, RG-normal: 0.2120, reconstruction validation: 0.0388
# Iteration 0023: RG-uniform: 0.2244, RG-normal: 0.2107, reconstruction validation: 0.0351
# Iteration 0024: RG-uniform: 0.2321, RG-normal: 0.2089, reconstruction validation: 0.0328
# Iteration 0025: RG-uniform: 0.2306, RG-normal: 0.2210, reconstruction validation: 0.0292
# Iteration 0026: RG-uniform: 0.2457, RG-normal: 0.2164, reconstruction validation: 0.0290
# Iteration 0027: RG-uniform: 0.2180, RG-normal: 0.2178, reconstruction validation: 0.0318
# Iteration 0028: RG-uniform: 0.2263, RG-normal: 0.2191, reconstruction validation: 0.0261
# Iteration 0029: RG-uniform: 0.2249, RG-normal: 0.2159, reconstruction validation: 0.0260
# Iteration 0030: RG-uniform: 0.2280, RG-normal: 0.2086, reconstruction validation: 0.0322
# Iteration 0031: RG-uniform: 0.2358, RG-normal: 0.2138, reconstruction validation: 0.0299
# Iteration 0032: RG-uniform: 0.2288, RG-normal: 0.2061, reconstruction validation: 0.0277
# Iteration 0033: RG-uniform: 0.2192, RG-normal: 0.1899, reconstruction validation: 0.0258
# Iteration 0034: RG-uniform: 0.2340, RG-normal: 0.2141, reconstruction validation: 0.0276
# Iteration 0035: RG-uniform: 0.2463, RG-normal: 0.2024, reconstruction validation: 0.0332
# Iteration 0036: RG-uniform: 0.2351, RG-normal: 0.2020, reconstruction validation: 0.0320
# Iteration 0037: RG-uniform: 0.2320, RG-normal: 0.2078, reconstruction validation: 0.0274
# Iteration 0038: RG-uniform: 0.2315, RG-normal: 0.2150, reconstruction validation: 0.0288
# Iteration 0039: RG-uniform: 0.2399, RG-normal: 0.2086, reconstruction validation: 0.0290
# Iteration 0040: RG-uniform: 0.2407, RG-normal: 0.2072, reconstruction validation: 0.0242
# Iteration 0041: RG-uniform: 0.2386, RG-normal: 0.2249, reconstruction validation: 0.0345
# Iteration 0042: RG-uniform: 0.2398, RG-normal: 0.2167, reconstruction validation: 0.0288
# Iteration 0043: RG-uniform: 0.2263, RG-normal: 0.2181, reconstruction validation: 0.0241
# Iteration 0044: RG-uniform: 0.2362, RG-normal: 0.2167, reconstruction validation: 0.0198
# Iteration 0045: RG-uniform: 0.2421, RG-normal: 0.2199, reconstruction validation: 0.0235
# Iteration 0046: RG-uniform: 0.2377, RG-normal: 0.2241, reconstruction validation: 0.0206
# Iteration 0047: RG-uniform: 0.2344, RG-normal: 0.2095, reconstruction validation: 0.0221
# Iteration 0048: RG-uniform: 0.2365, RG-normal: 0.2116, reconstruction validation: 0.0178
# Iteration 0049: RG-uniform: 0.2193, RG-normal: 0.1981, reconstruction validation: 0.0209
# Iteration 0050: RG-uniform: 0.2445, RG-normal: 0.2111, reconstruction validation: 0.0216
# Iteration 0051: RG-uniform: 0.2260, RG-normal: 0.2076, reconstruction validation: 0.0186
# Iteration 0052: RG-uniform: 0.2460, RG-normal: 0.2091, reconstruction validation: 0.0180
# Iteration 0053: RG-uniform: 0.2442, RG-normal: 0.2221, reconstruction validation: 0.0221
# Iteration 0054: RG-uniform: 0.2294, RG-normal: 0.2049, reconstruction validation: 0.0166
# Iteration 0055: RG-uniform: 0.2457, RG-normal: 0.2111, reconstruction validation: 0.0177
# Iteration 0056: RG-uniform: 0.2134, RG-normal: 0.1983, reconstruction validation: 0.0183
# Iteration 0057: RG-uniform: 0.2365, RG-normal: 0.2174, reconstruction validation: 0.0201
# Iteration 0058: RG-uniform: 0.2154, RG-normal: 0.1998, reconstruction validation: 0.0152
# Iteration 0059: RG-uniform: 0.2245, RG-normal: 0.1906, reconstruction validation: 0.0177
# Iteration 0060: RG-uniform: 0.2295, RG-normal: 0.1939, reconstruction validation: 0.0182
# Iteration 0061: RG-uniform: 0.2262, RG-normal: 0.2016, reconstruction validation: 0.0185
# Iteration 0062: RG-uniform: 0.2260, RG-normal: 0.2251, reconstruction validation: 0.0171
# Iteration 0063: RG-uniform: 0.2306, RG-normal: 0.2271, reconstruction validation: 0.0161
# Iteration 0064: RG-uniform: 0.2352, RG-normal: 0.2219, reconstruction validation: 0.0173
# Iteration 0065: RG-uniform: 0.2248, RG-normal: 0.2101, reconstruction validation: 0.0188
# Iteration 0066: RG-uniform: 0.2243, RG-normal: 0.2039, reconstruction validation: 0.0163
# Iteration 0067: RG-uniform: 0.2252, RG-normal: 0.2024, reconstruction validation: 0.0203
# Iteration 0068: RG-uniform: 0.2115, RG-normal: 0.2033, reconstruction validation: 0.0214
# Iteration 0069: RG-uniform: 0.2255, RG-normal: 0.2133, reconstruction validation: 0.0243
# Iteration 0070: RG-uniform: 0.2443, RG-normal: 0.2120, reconstruction validation: 0.0301
# Iteration 0071: RG-uniform: 0.2225, RG-normal: 0.2056, reconstruction validation: 0.0173
# Iteration 0072: RG-uniform: 0.2149, RG-normal: 0.2145, reconstruction validation: 0.0163
# Iteration 0073: RG-uniform: 0.2264, RG-normal: 0.2119, reconstruction validation: 0.0176
# Iteration 0074: RG-uniform: 0.2282, RG-normal: 0.2266, reconstruction validation: 0.0224
# Iteration 0075: RG-uniform: 0.2196, RG-normal: 0.2077, reconstruction validation: 0.0224
# Iteration 0076: RG-uniform: 0.2148, RG-normal: 0.2032, reconstruction validation: 0.0206
# Iteration 0077: RG-uniform: 0.2224, RG-normal: 0.2136, reconstruction validation: 0.0218
# Iteration 0078: RG-uniform: 0.2303, RG-normal: 0.2046, reconstruction validation: 0.0264
# Iteration 0079: RG-uniform: 0.2240, RG-normal: 0.2187, reconstruction validation: 0.0208
# Iteration 0080: RG-uniform: 0.2261, RG-normal: 0.2096, reconstruction validation: 0.0237
# Iteration 0081: RG-uniform: 0.2154, RG-normal: 0.2024, reconstruction validation: 0.0234
# Iteration 0082: RG-uniform: 0.2273, RG-normal: 0.1840, reconstruction validation: 0.0224
# Iteration 0083: RG-uniform: 0.2246, RG-normal: 0.2016, reconstruction validation: 0.0209
# Iteration 0084: RG-uniform: 0.2245, RG-normal: 0.2186, reconstruction validation: 0.0221
# Iteration 0085: RG-uniform: 0.2205, RG-normal: 0.1908, reconstruction validation: 0.0179
# Iteration 0086: RG-uniform: 0.2262, RG-normal: 0.2077, reconstruction validation: 0.0204
# Iteration 0087: RG-uniform: 0.2380, RG-normal: 0.2059, reconstruction validation: 0.0245
# Iteration 0088: RG-uniform: 0.2305, RG-normal: 0.1981, reconstruction validation: 0.0166
# Iteration 0089: RG-uniform: 0.2226, RG-normal: 0.2078, reconstruction validation: 0.0143
# Iteration 0090: RG-uniform: 0.2198, RG-normal: 0.2093, reconstruction validation: 0.0166
# Iteration 0091: RG-uniform: 0.2312, RG-normal: 0.1950, reconstruction validation: 0.0175
# Iteration 0092: RG-uniform: 0.2314, RG-normal: 0.2101, reconstruction validation: 0.0192
# Iteration 0093: RG-uniform: 0.2184, RG-normal: 0.2097, reconstruction validation: 0.0179
# Iteration 0094: RG-uniform: 0.2438, RG-normal: 0.2103, reconstruction validation: 0.0165
# Iteration 0095: RG-uniform: 0.2119, RG-normal: 0.1983, reconstruction validation: 0.0135
# Iteration 0096: RG-uniform: 0.2298, RG-normal: 0.2080, reconstruction validation: 0.0172
# Iteration 0097: RG-uniform: 0.2299, RG-normal: 0.2092, reconstruction validation: 0.0178
# Iteration 0098: RG-uniform: 0.2287, RG-normal: 0.2041, reconstruction validation: 0.0180
# Iteration 0099: RG-uniform: 0.2251, RG-normal: 0.2021, reconstruction validation: 0.0155
# Iteration 0100: RG-uniform: 0.2386, RG-normal: 0.2169, reconstruction validation: 0.0143
# split level = 3
# Iteration 0001: RG-uniform: 0.2121, RG-normal: 0.2015, reconstruction validation: 0.0539
# Iteration 0002: RG-uniform: 0.2348, RG-normal: 0.2246, reconstruction validation: 0.0374
# Iteration 0003: RG-uniform: 0.2462, RG-normal: 0.2135, reconstruction validation: 0.0356
# Iteration 0004: RG-uniform: 0.2189, RG-normal: 0.2126, reconstruction validation: 0.0317
# Iteration 0005: RG-uniform: 0.2318, RG-normal: 0.2157, reconstruction validation: 0.0198
# Iteration 0006: RG-uniform: 0.2406, RG-normal: 0.2158, reconstruction validation: 0.0189
# Iteration 0007: RG-uniform: 0.2150, RG-normal: 0.2003, reconstruction validation: 0.0165
# Iteration 0008: RG-uniform: 0.2309, RG-normal: 0.2234, reconstruction validation: 0.0146
# Iteration 0009: RG-uniform: 0.2304, RG-normal: 0.2050, reconstruction validation: 0.0111
# Iteration 0010: RG-uniform: 0.2303, RG-normal: 0.2061, reconstruction validation: 0.0103
# Iteration 0011: RG-uniform: 0.2282, RG-normal: 0.2021, reconstruction validation: 0.0130
# Iteration 0012: RG-uniform: 0.2301, RG-normal: 0.2136, reconstruction validation: 0.0153
# Iteration 0013: RG-uniform: 0.2332, RG-normal: 0.1961, reconstruction validation: 0.0128
# Iteration 0014: RG-uniform: 0.2249, RG-normal: 0.2046, reconstruction validation: 0.0068
# Iteration 0015: RG-uniform: 0.2162, RG-normal: 0.2209, reconstruction validation: 0.0049
# Iteration 0016: RG-uniform: 0.2351, RG-normal: 0.2071, reconstruction validation: 0.0060
# Iteration 0017: RG-uniform: 0.2276, RG-normal: 0.2225, reconstruction validation: 0.0061
# Iteration 0018: RG-uniform: 0.2430, RG-normal: 0.2222, reconstruction validation: 0.0048
# Iteration 0019: RG-uniform: 0.2294, RG-normal: 0.2116, reconstruction validation: 0.0058
# Iteration 0020: RG-uniform: 0.2351, RG-normal: 0.2080, reconstruction validation: 0.0047
# Iteration 0021: RG-uniform: 0.2317, RG-normal: 0.2218, reconstruction validation: 0.0036
# Iteration 0022: RG-uniform: 0.2356, RG-normal: 0.2100, reconstruction validation: 0.0043
# Iteration 0023: RG-uniform: 0.2378, RG-normal: 0.2008, reconstruction validation: 0.0060
# Iteration 0024: RG-uniform: 0.2239, RG-normal: 0.2059, reconstruction validation: 0.0067
# Iteration 0025: RG-uniform: 0.2318, RG-normal: 0.2025, reconstruction validation: 0.0082
# Iteration 0026: RG-uniform: 0.2354, RG-normal: 0.2364, reconstruction validation: 0.0042
# Iteration 0027: RG-uniform: 0.2126, RG-normal: 0.2114, reconstruction validation: 0.0052
# Iteration 0028: RG-uniform: 0.2443, RG-normal: 0.2082, reconstruction validation: 0.0040
# Iteration 0029: RG-uniform: 0.2240, RG-normal: 0.2064, reconstruction validation: 0.0070
# Iteration 0030: RG-uniform: 0.2213, RG-normal: 0.2094, reconstruction validation: 0.0051
# Iteration 0031: RG-uniform: 0.2287, RG-normal: 0.2183, reconstruction validation: 0.0047
# Iteration 0032: RG-uniform: 0.2062, RG-normal: 0.2005, reconstruction validation: 0.0055
# Iteration 0033: RG-uniform: 0.2339, RG-normal: 0.2221, reconstruction validation: 0.0048
# Iteration 0034: RG-uniform: 0.2251, RG-normal: 0.2091, reconstruction validation: 0.0051
# Iteration 0035: RG-uniform: 0.2454, RG-normal: 0.2223, reconstruction validation: 0.0034
# Iteration 0036: RG-uniform: 0.2492, RG-normal: 0.2222, reconstruction validation: 0.0033
# Iteration 0037: RG-uniform: 0.2530, RG-normal: 0.2253, reconstruction validation: 0.0034
# Iteration 0038: RG-uniform: 0.2351, RG-normal: 0.2212, reconstruction validation: 0.0035
# Iteration 0039: RG-uniform: 0.2192, RG-normal: 0.2106, reconstruction validation: 0.0045
# Iteration 0040: RG-uniform: 0.2442, RG-normal: 0.2095, reconstruction validation: 0.0042
# Iteration 0041: RG-uniform: 0.2431, RG-normal: 0.2167, reconstruction validation: 0.0037
# Iteration 0042: RG-uniform: 0.2282, RG-normal: 0.2083, reconstruction validation: 0.0031
# Iteration 0043: RG-uniform: 0.2192, RG-normal: 0.2002, reconstruction validation: 0.0043
# Iteration 0044: RG-uniform: 0.2371, RG-normal: 0.2112, reconstruction validation: 0.0026
# Iteration 0045: RG-uniform: 0.2516, RG-normal: 0.1991, reconstruction validation: 0.0034
# Iteration 0046: RG-uniform: 0.2345, RG-normal: 0.2117, reconstruction validation: 0.0025
# Iteration 0047: RG-uniform: 0.2524, RG-normal: 0.2145, reconstruction validation: 0.0053
# Iteration 0048: RG-uniform: 0.2344, RG-normal: 0.2183, reconstruction validation: 0.0026
# Iteration 0049: RG-uniform: 0.2225, RG-normal: 0.2175, reconstruction validation: 0.0030
# Iteration 0050: RG-uniform: 0.2164, RG-normal: 0.2170, reconstruction validation: 0.0032
# Iteration 0051: RG-uniform: 0.2266, RG-normal: 0.2132, reconstruction validation: 0.0048
# Iteration 0052: RG-uniform: 0.2043, RG-normal: 0.1981, reconstruction validation: 0.0055
# Iteration 0053: RG-uniform: 0.2450, RG-normal: 0.2134, reconstruction validation: 0.0045
# Iteration 0054: RG-uniform: 0.2345, RG-normal: 0.2089, reconstruction validation: 0.0045
# Iteration 0055: RG-uniform: 0.2387, RG-normal: 0.1985, reconstruction validation: 0.0038
# Iteration 0056: RG-uniform: 0.2457, RG-normal: 0.2329, reconstruction validation: 0.0054
# Iteration 0057: RG-uniform: 0.2444, RG-normal: 0.2156, reconstruction validation: 0.0037
# Iteration 0058: RG-uniform: 0.2213, RG-normal: 0.2131, reconstruction validation: 0.0049
# Iteration 0059: RG-uniform: 0.2354, RG-normal: 0.2092, reconstruction validation: 0.0039
# Iteration 0060: RG-uniform: 0.2263, RG-normal: 0.1984, reconstruction validation: 0.0032
# Iteration 0061: RG-uniform: 0.2425, RG-normal: 0.2381, reconstruction validation: 0.0021
# Iteration 0062: RG-uniform: 0.2255, RG-normal: 0.2073, reconstruction validation: 0.0040
# Iteration 0063: RG-uniform: 0.2373, RG-normal: 0.2173, reconstruction validation: 0.0035
# Iteration 0064: RG-uniform: 0.2377, RG-normal: 0.2109, reconstruction validation: 0.0036
# Iteration 0065: RG-uniform: 0.2531, RG-normal: 0.2169, reconstruction validation: 0.0057
# Iteration 0066: RG-uniform: 0.2342, RG-normal: 0.2140, reconstruction validation: 0.0041
# Iteration 0067: RG-uniform: 0.2375, RG-normal: 0.2288, reconstruction validation: 0.0025
# Iteration 0068: RG-uniform: 0.2346, RG-normal: 0.2058, reconstruction validation: 0.0032
# Iteration 0069: RG-uniform: 0.2263, RG-normal: 0.2121, reconstruction validation: 0.0032
# Iteration 0070: RG-uniform: 0.2331, RG-normal: 0.2117, reconstruction validation: 0.0028
# Iteration 0071: RG-uniform: 0.2319, RG-normal: 0.2155, reconstruction validation: 0.0035
# Iteration 0072: RG-uniform: 0.2216, RG-normal: 0.2086, reconstruction validation: 0.0047
# Iteration 0073: RG-uniform: 0.2318, RG-normal: 0.2281, reconstruction validation: 0.0033
# Iteration 0074: RG-uniform: 0.2442, RG-normal: 0.2163, reconstruction validation: 0.0052
# Iteration 0075: RG-uniform: 0.2476, RG-normal: 0.2070, reconstruction validation: 0.0055
# Iteration 0076: RG-uniform: 0.2357, RG-normal: 0.2014, reconstruction validation: 0.0053
# Iteration 0077: RG-uniform: 0.2371, RG-normal: 0.2169, reconstruction validation: 0.0046
# Iteration 0078: RG-uniform: 0.2310, RG-normal: 0.1942, reconstruction validation: 0.0044
# Iteration 0079: RG-uniform: 0.2194, RG-normal: 0.2078, reconstruction validation: 0.0037
# Iteration 0080: RG-uniform: 0.2304, RG-normal: 0.2014, reconstruction validation: 0.0047
# Iteration 0081: RG-uniform: 0.2126, RG-normal: 0.2160, reconstruction validation: 0.0027
# Iteration 0082: RG-uniform: 0.2433, RG-normal: 0.2175, reconstruction validation: 0.0038
# Iteration 0083: RG-uniform: 0.2243, RG-normal: 0.2010, reconstruction validation: 0.0056
# Iteration 0084: RG-uniform: 0.2253, RG-normal: 0.2075, reconstruction validation: 0.0071
# Iteration 0085: RG-uniform: 0.2274, RG-normal: 0.2197, reconstruction validation: 0.0030
# Iteration 0086: RG-uniform: 0.2187, RG-normal: 0.2079, reconstruction validation: 0.0048
# Iteration 0087: RG-uniform: 0.2440, RG-normal: 0.2175, reconstruction validation: 0.0042
# Iteration 0088: RG-uniform: 0.2325, RG-normal: 0.2103, reconstruction validation: 0.0032
# Iteration 0089: RG-uniform: 0.2217, RG-normal: 0.2156, reconstruction validation: 0.0025
# Iteration 0090: RG-uniform: 0.2293, RG-normal: 0.2040, reconstruction validation: 0.0055
# Iteration 0091: RG-uniform: 0.2217, RG-normal: 0.2064, reconstruction validation: 0.0044
# Iteration 0092: RG-uniform: 0.2172, RG-normal: 0.2075, reconstruction validation: 0.0040
# Iteration 0093: RG-uniform: 0.2422, RG-normal: 0.1956, reconstruction validation: 0.0068
# Iteration 0094: RG-uniform: 0.2240, RG-normal: 0.1998, reconstruction validation: 0.0030
# Iteration 0095: RG-uniform: 0.2317, RG-normal: 0.1987, reconstruction validation: 0.0048
# Iteration 0096: RG-uniform: 0.2352, RG-normal: 0.2132, reconstruction validation: 0.0044
# Iteration 0097: RG-uniform: 0.2173, RG-normal: 0.2014, reconstruction validation: 0.0037
# Iteration 0098: RG-uniform: 0.2166, RG-normal: 0.2025, reconstruction validation: 0.0039
# Iteration 0099: RG-uniform: 0.2370, RG-normal: 0.2124, reconstruction validation: 0.0042
# Iteration 0100: RG-uniform: 0.2203, RG-normal: 0.2087, reconstruction validation: 0.0039
# split level = 2
# Iteration 0001: RG-uniform: 0.2362, RG-normal: 0.2101, reconstruction validation: 0.0196
# Iteration 0002: RG-uniform: 0.2351, RG-normal: 0.2165, reconstruction validation: 0.0041
# Iteration 0003: RG-uniform: 0.2436, RG-normal: 0.2325, reconstruction validation: 0.0025
# Iteration 0004: RG-uniform: 0.2133, RG-normal: 0.2075, reconstruction validation: 0.0021
# Iteration 0005: RG-uniform: 0.2241, RG-normal: 0.1970, reconstruction validation: 0.0010
# Iteration 0006: RG-uniform: 0.2202, RG-normal: 0.2212, reconstruction validation: 0.0022
# Iteration 0007: RG-uniform: 0.2337, RG-normal: 0.2241, reconstruction validation: 0.0013
# Iteration 0008: RG-uniform: 0.2300, RG-normal: 0.2016, reconstruction validation: 0.0017
# Iteration 0009: RG-uniform: 0.2429, RG-normal: 0.2180, reconstruction validation: 0.0009
# Iteration 0010: RG-uniform: 0.2287, RG-normal: 0.2076, reconstruction validation: 0.0019
# Iteration 0011: RG-uniform: 0.2357, RG-normal: 0.2152, reconstruction validation: 0.0011
# Iteration 0012: RG-uniform: 0.2421, RG-normal: 0.2025, reconstruction validation: 0.0013
# Iteration 0013: RG-uniform: 0.2242, RG-normal: 0.2054, reconstruction validation: 0.0024
# Iteration 0014: RG-uniform: 0.2254, RG-normal: 0.2169, reconstruction validation: 0.0010
# Iteration 0015: RG-uniform: 0.2385, RG-normal: 0.2182, reconstruction validation: 0.0011
# Iteration 0016: RG-uniform: 0.2359, RG-normal: 0.2068, reconstruction validation: 0.0011
# Iteration 0017: RG-uniform: 0.2398, RG-normal: 0.2163, reconstruction validation: 0.0011
# Iteration 0018: RG-uniform: 0.2402, RG-normal: 0.2290, reconstruction validation: 0.0009
# Iteration 0019: RG-uniform: 0.2234, RG-normal: 0.2002, reconstruction validation: 0.0012
# Iteration 0020: RG-uniform: 0.2443, RG-normal: 0.2159, reconstruction validation: 0.0013
# Iteration 0021: RG-uniform: 0.2248, RG-normal: 0.2142, reconstruction validation: 0.0010
# Iteration 0022: RG-uniform: 0.2332, RG-normal: 0.2130, reconstruction validation: 0.0013
# Iteration 0023: RG-uniform: 0.2345, RG-normal: 0.2133, reconstruction validation: 0.0010
# Iteration 0024: RG-uniform: 0.2378, RG-normal: 0.2098, reconstruction validation: 0.0016
# Iteration 0025: RG-uniform: 0.2341, RG-normal: 0.2144, reconstruction validation: 0.0012
# Iteration 0026: RG-uniform: 0.2141, RG-normal: 0.2180, reconstruction validation: 0.0013
# Iteration 0027: RG-uniform: 0.2408, RG-normal: 0.2208, reconstruction validation: 0.0010
# Iteration 0028: RG-uniform: 0.2307, RG-normal: 0.2161, reconstruction validation: 0.0010
# Iteration 0029: RG-uniform: 0.2253, RG-normal: 0.2123, reconstruction validation: 0.0012
# Iteration 0030: RG-uniform: 0.2446, RG-normal: 0.2218, reconstruction validation: 0.0008
# Iteration 0031: RG-uniform: 0.2210, RG-normal: 0.2191, reconstruction validation: 0.0014
# Iteration 0032: RG-uniform: 0.2380, RG-normal: 0.2079, reconstruction validation: 0.0010
# Iteration 0033: RG-uniform: 0.2416, RG-normal: 0.2108, reconstruction validation: 0.0015
# Iteration 0034: RG-uniform: 0.2283, RG-normal: 0.2227, reconstruction validation: 0.0025
# Iteration 0035: RG-uniform: 0.2145, RG-normal: 0.2101, reconstruction validation: 0.0013
# Iteration 0036: RG-uniform: 0.2336, RG-normal: 0.1994, reconstruction validation: 0.0014
# Iteration 0037: RG-uniform: 0.2557, RG-normal: 0.2046, reconstruction validation: 0.0014
# Iteration 0038: RG-uniform: 0.2415, RG-normal: 0.2167, reconstruction validation: 0.0019
# Iteration 0039: RG-uniform: 0.2203, RG-normal: 0.2090, reconstruction validation: 0.0017
# Iteration 0040: RG-uniform: 0.2217, RG-normal: 0.2101, reconstruction validation: 0.0016
# Iteration 0041: RG-uniform: 0.2390, RG-normal: 0.1998, reconstruction validation: 0.0015
# Iteration 0042: RG-uniform: 0.2367, RG-normal: 0.2056, reconstruction validation: 0.0023
# Iteration 0043: RG-uniform: 0.2226, RG-normal: 0.1873, reconstruction validation: 0.0016
# Iteration 0044: RG-uniform: 0.2275, RG-normal: 0.2145, reconstruction validation: 0.0023
# Iteration 0045: RG-uniform: 0.2287, RG-normal: 0.2199, reconstruction validation: 0.0034
# Iteration 0046: RG-uniform: 0.2413, RG-normal: 0.2169, reconstruction validation: 0.0018
# Iteration 0047: RG-uniform: 0.2287, RG-normal: 0.2054, reconstruction validation: 0.0019
# Iteration 0048: RG-uniform: 0.2427, RG-normal: 0.2094, reconstruction validation: 0.0019
# Iteration 0049: RG-uniform: 0.2418, RG-normal: 0.2141, reconstruction validation: 0.0021
# Iteration 0050: RG-uniform: 0.2340, RG-normal: 0.2050, reconstruction validation: 0.0023
# Iteration 0051: RG-uniform: 0.2284, RG-normal: 0.2161, reconstruction validation: 0.0019
# Iteration 0052: RG-uniform: 0.2267, RG-normal: 0.2155, reconstruction validation: 0.0015
# Iteration 0053: RG-uniform: 0.2279, RG-normal: 0.2086, reconstruction validation: 0.0027
# Iteration 0054: RG-uniform: 0.2304, RG-normal: 0.2187, reconstruction validation: 0.0025
# Iteration 0055: RG-uniform: 0.2226, RG-normal: 0.2181, reconstruction validation: 0.0023
# Iteration 0056: RG-uniform: 0.2234, RG-normal: 0.2007, reconstruction validation: 0.0016
# Iteration 0057: RG-uniform: 0.2312, RG-normal: 0.2115, reconstruction validation: 0.0031
# Iteration 0058: RG-uniform: 0.2498, RG-normal: 0.2138, reconstruction validation: 0.0029
# Iteration 0059: RG-uniform: 0.2387, RG-normal: 0.2058, reconstruction validation: 0.0023
# Iteration 0060: RG-uniform: 0.2425, RG-normal: 0.2202, reconstruction validation: 0.0023
# Iteration 0061: RG-uniform: 0.2212, RG-normal: 0.2102, reconstruction validation: 0.0026
# Iteration 0062: RG-uniform: 0.2178, RG-normal: 0.2121, reconstruction validation: 0.0023
# Iteration 0063: RG-uniform: 0.2311, RG-normal: 0.2179, reconstruction validation: 0.0020
# Iteration 0064: RG-uniform: 0.2075, RG-normal: 0.1858, reconstruction validation: 0.0030
# Iteration 0065: RG-uniform: 0.2361, RG-normal: 0.2019, reconstruction validation: 0.0026
# Iteration 0066: RG-uniform: 0.2478, RG-normal: 0.2020, reconstruction validation: 0.0039
# Iteration 0067: RG-uniform: 0.2273, RG-normal: 0.2232, reconstruction validation: 0.0019
# Iteration 0068: RG-uniform: 0.2377, RG-normal: 0.1965, reconstruction validation: 0.0017
# Iteration 0069: RG-uniform: 0.2210, RG-normal: 0.2061, reconstruction validation: 0.0021
# Iteration 0070: RG-uniform: 0.2208, RG-normal: 0.2014, reconstruction validation: 0.0018
# Iteration 0071: RG-uniform: 0.2204, RG-normal: 0.2026, reconstruction validation: 0.0016
# Iteration 0072: RG-uniform: 0.2332, RG-normal: 0.2123, reconstruction validation: 0.0044
# Iteration 0073: RG-uniform: 0.2320, RG-normal: 0.2060, reconstruction validation: 0.0039
# Iteration 0074: RG-uniform: 0.2219, RG-normal: 0.2093, reconstruction validation: 0.0021
# Iteration 0075: RG-uniform: 0.2342, RG-normal: 0.2064, reconstruction validation: 0.0022
# Iteration 0076: RG-uniform: 0.2257, RG-normal: 0.2112, reconstruction validation: 0.0033
# Iteration 0077: RG-uniform: 0.2305, RG-normal: 0.1869, reconstruction validation: 0.0017
# Iteration 0078: RG-uniform: 0.2234, RG-normal: 0.2066, reconstruction validation: 0.0036
# Iteration 0079: RG-uniform: 0.2275, RG-normal: 0.2043, reconstruction validation: 0.0016
# Iteration 0080: RG-uniform: 0.2210, RG-normal: 0.2152, reconstruction validation: 0.0019
# Iteration 0081: RG-uniform: 0.2282, RG-normal: 0.2002, reconstruction validation: 0.0018
# Iteration 0082: RG-uniform: 0.2500, RG-normal: 0.2018, reconstruction validation: 0.0022
# Iteration 0083: RG-uniform: 0.2222, RG-normal: 0.2198, reconstruction validation: 0.0025
# Iteration 0084: RG-uniform: 0.2262, RG-normal: 0.2128, reconstruction validation: 0.0021
# Iteration 0085: RG-uniform: 0.2497, RG-normal: 0.2052, reconstruction validation: 0.0016
# Iteration 0086: RG-uniform: 0.2432, RG-normal: 0.2072, reconstruction validation: 0.0022
# Iteration 0087: RG-uniform: 0.2521, RG-normal: 0.2273, reconstruction validation: 0.0025
# Iteration 0088: RG-uniform: 0.2311, RG-normal: 0.2123, reconstruction validation: 0.0021
# Iteration 0089: RG-uniform: 0.2470, RG-normal: 0.2003, reconstruction validation: 0.0027
# Iteration 0090: RG-uniform: 0.2150, RG-normal: 0.1893, reconstruction validation: 0.0021
# Iteration 0091: RG-uniform: 0.2235, RG-normal: 0.2194, reconstruction validation: 0.0019
# Iteration 0092: RG-uniform: 0.2358, RG-normal: 0.1950, reconstruction validation: 0.0021
# Iteration 0093: RG-uniform: 0.2212, RG-normal: 0.2086, reconstruction validation: 0.0028
# Iteration 0094: RG-uniform: 0.2416, RG-normal: 0.2113, reconstruction validation: 0.0022
# Iteration 0095: RG-uniform: 0.2199, RG-normal: 0.1988, reconstruction validation: 0.0020
# Iteration 0096: RG-uniform: 0.2263, RG-normal: 0.2186, reconstruction validation: 0.0021
# Iteration 0097: RG-uniform: 0.2278, RG-normal: 0.2121, reconstruction validation: 0.0022
# Iteration 0098: RG-uniform: 0.2326, RG-normal: 0.2029, reconstruction validation: 0.0026
# Iteration 0099: RG-uniform: 0.2256, RG-normal: 0.1991, reconstruction validation: 0.0022
# Iteration 0100: RG-uniform: 0.2188, RG-normal: 0.2117, reconstruction validation: 0.0020

# %%
import pickle
with open('./log/credit.pkl', 'wb') as f:
    pickle.dump(log_attack, f)

# %%
import matplotlib.pyplot as plt

plt.xlim([0,100])
plt.ylim([0,0.35])
plt.grid()
plt.ylabel('MSE per feature')
plt.xlabel('Batch distance from the obtained model snapshot')
ran = [i+1 for i in range(100)]
plt.plot(
    ran, log_attack[2][:,0], 'co-',
    ran, log_attack[2][:,1], 'mv-',
    ran, log_attack[2][:,2], 'gD-',
    ran, log_attack[3][:,2], 'r^-',
    ran, log_attack[4][:,2], 'bs-',
    markevery=np.arange(0, 101, 9))
plt.legend(['RG-uniform', 'RG-normal', 'MRA ($h_c=2$)', 'MRA ($h_c=3$)', 'MRA ($h_C=4$)'], loc='upper center', ncol=3)
plt.savefig("fig/credit.pdf", bbox_inches='tight')
