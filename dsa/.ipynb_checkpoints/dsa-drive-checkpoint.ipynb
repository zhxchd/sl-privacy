# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

import dsa
from dsa import *
from models import mlp
import pickle
from sklearn.model_selection import train_test_split

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
def make_dataset(X, Y, f):
    x = tf.data.Dataset.from_tensor_slices(X)
    y = tf.data.Dataset.from_tensor_slices(Y)
    x = x.map(f)
    xy = tf.data.Dataset.zip((x, y))
    xy = xy.shuffle(10000)
    return xy

aux_target_ratio = 0.2

xy = np.loadtxt("../datasets/drive-diagnosis.txt")
np.random.shuffle(xy)
x = xy[:,0:-1]
y = xy[:,-1]

x = (x - np.min(x, axis=0))/(np.max(x, axis=0) - np.min(x, axis=0))
y = y.reshape((len(x), 1)).astype("float32")-1

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=aux_target_ratio/(aux_target_ratio+1), random_state=42)

target_ds = make_dataset(x_train, y_train, lambda t: t)
aux_ds = make_dataset(x_test, y_test, lambda t: t)
# Out:
# 2022-03-31 02:24:37.281054: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-31 02:24:37.281121: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: xgpd0
# 2022-03-31 02:24:37.281136: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: xgpd0
# 2022-03-31 02:24:37.281279: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.103.1
# 2022-03-31 02:24:37.281323: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.103.1
# 2022-03-31 02:24:37.281333: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.103.1
# 2022-03-31 02:24:37.281807: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
drive_dsa = {}
log_drive_dsa = {}

for split in [4,3,2]:
    make_f, make_g, make_e, make_d, make_c = mlp.make_mlp(attr_num=48, class_num=11, split=split, units=256, ed_act="sigmoid")
    drive_dsa[split] = dsa(target_ds=target_ds, aux_ds=aux_ds)
    print("============================")
    print("======Split level is {}======".format(split))
    print("============================")
    log_drive_dsa[split] = drive_dsa[split].dsa_attack(
        make_f=make_f,
        make_g=make_g,
        lr=0.001,
        loss_fn=tf.keras.losses.SparseCategoricalCrossentropy(),
        acc_fn=tf.keras.metrics.SparseCategoricalAccuracy(),
        batch_size=32,
        iterations=1000,
        make_e=make_e,
        make_d=make_d,
        make_c=make_c,
        lr_e=0.001, # learning rate of the encoder/decoder/critic is set to be smaller
        lr_d=0.001,
        lr_c=0.001,
        log_freq=200)
# Out:
# ============================
# ======Split level is 4======
# ============================
# Iteration 200, train accuracy: 0.3475813860632479, average attack MSE: 0.014194136895239353
# Iteration 400, train accuracy: 0.5415093697607517, average attack MSE: 0.011649489644914865
# Iteration 600, train accuracy: 0.6180684757232666, average attack MSE: 0.011680805939249694
# Iteration 800, train accuracy: 0.6637929424643516, average attack MSE: 0.011653732450213283
# Iteration 1000, train accuracy: 0.6911612850427628, average attack MSE: 0.011412773632910102
# ============================
# ======Split level is 3======
# ============================
# Iteration 200, train accuracy: 0.30810983836650846, average attack MSE: 0.014347937563434244
# Iteration 400, train accuracy: 0.4586920893192291, average attack MSE: 0.011632793790195137
# Iteration 600, train accuracy: 0.5400241538882256, average attack MSE: 0.01168521124869585
# Iteration 800, train accuracy: 0.60508515894413, average attack MSE: 0.011743670776486397
# Iteration 1000, train accuracy: 0.6437752342224121, average attack MSE: 0.011694792937487365
# ============================
# ======Split level is 2======
# ============================
# Iteration 200, train accuracy: 0.3159758583456278, average attack MSE: 0.014443235294893384
# Iteration 400, train accuracy: 0.5033445486426353, average attack MSE: 0.011592007982544601
# Iteration 600, train accuracy: 0.5915662881731987, average attack MSE: 0.011777736591175198
# Iteration 800, train accuracy: 0.6422368359565734, average attack MSE: 0.011765412441454827
# Iteration 1000, train accuracy: 0.6777150079607963, average attack MSE: 0.011745979292318225

# %%
from fsha import *

drive_fsha={}
log_drive_fsha={}

for split in [4,3,2]:
    print("============================")
    print("======Split level is {}======".format(split))
    print("============================")
    hparams = {
        'WGAN' : False,
        'style_loss' : None,
        'lr_f' :  0.001,
        'lr_tilde': 0.001,
        'lr_D': 0.001,
        'lr_g': 0.001
    }
    make_f, make_g, make_e, make_d, make_c = mlp.make_mlp(attr_num=48, class_num=11, split=split, units=256, ed_act="sigmoid")
    models = (make_f, make_g, make_e, make_d, make_c)
    drive_fsha[split] = FSHA(
        target_ds, aux_ds,
        loss_fn=tf.keras.losses.SparseCategoricalCrossentropy(),
        acc_fn=tf.keras.metrics.SparseCategoricalAccuracy(), models=models, batch_size=32, hparams=hparams)
    log_drive_fsha[split]=drive_fsha[split](1000, verbose=True, progress_bar=False, log_frequency=200)
# Out:
# ============================
# ======Split level is 4======
# ============================
# RUNNING...
# Iteration 0000000 train accuracy: 0.0000, validation: 0.0994
# Iteration 0000200 train accuracy: 0.0878, validation: 0.0141
# Iteration 0000400 train accuracy: 0.0936, validation: 0.0119
# Iteration 0000600 train accuracy: 0.0955, validation: 0.0120
# Iteration 0000800 train accuracy: 0.0948, validation: 0.0118
# ============================
# ======Split level is 3======
# ============================
# RUNNING...
# Iteration 0000000 train accuracy: 0.0312, validation: 0.1054
# Iteration 0000200 train accuracy: 0.0886, validation: 0.0139
# Iteration 0000400 train accuracy: 0.0886, validation: 0.0119
# Iteration 0000600 train accuracy: 0.0875, validation: 0.0120
# Iteration 0000800 train accuracy: 0.0895, validation: 0.0121
# ============================
# ======Split level is 2======
# ============================
# RUNNING...
# Iteration 0000000 train accuracy: 0.0000, validation: 0.1192
# Iteration 0000200 train accuracy: 0.1252, validation: 0.0143
# Iteration 0000400 train accuracy: 0.1104, validation: 0.0118
# Iteration 0000600 train accuracy: 0.1050, validation: 0.0120
# Iteration 0000800 train accuracy: 0.1026, validation: 0.0119

# %%
with open('log/drive-dsa.pkl', 'wb') as f:
    pickle.dump(log_drive_dsa, f)
with open('log/drive-fsha.pkl', 'wb') as f:
    pickle.dump(log_drive_fsha, f)

# %%
from matplotlib.pyplot import figure
# figure(figsize=(6.4,4.8))
log_freq = 25
# plt.yscale('logit')
plt.xlim([0,1000])
plt.grid()

sampled_loss = {}
sampled_fsha_loss = {}

for split in [2,3,4]:
    sampled_loss[split] = [sum(log_drive_dsa[split][:,2][i*log_freq:(i+1)*log_freq])/log_freq for i in range(int(len(log_drive_dsa[split][:,0])/log_freq))]
    sampled_fsha_loss[split] = [sum(log_drive_fsha[split][:,2][i*log_freq:(i+1)*log_freq])/log_freq for i in range(int(len(log_drive_fsha[split][:,0])/log_freq))]
ran = [i * log_freq + log_freq/2 for i in range(int(1000/log_freq))]
plt.ylabel('MSE per feature')
plt.xlabel('Iteration')
plt.plot(ran, sampled_loss[2], 'ro-', ran, sampled_loss[3], 'b^-', ran, sampled_loss[4], 'gs-', markevery=13)
plt.plot(ran, sampled_fsha_loss[2], 'ro:', ran, sampled_fsha_loss[3], 'b^:', ran, sampled_fsha_loss[4], 'gs:', markevery=13)
# ax2=plt.gca().twinx()
# ax2.plot(ran, sampled_acc[2], 'ro-', ran, sampled_acc[3], 'b^-', ran, sampled_acc[4], 'gs-', markevery=7)
plt.legend(["DSA ($h=2$)", "DSA ($h=3$)", "DSA ($h=4$)", "FSHA ($h=2$)", "FSHA ($h=3$)", "FSHA ($h=4$)"])
plt.savefig("fig/drive.pdf", bbox_inches='tight')

# %%
from matplotlib.pyplot import figure
# figure(figsize=(6.4,4.8))
log_freq = 25
# plt.yscale('logit')
plt.xlim([0,1000])
plt.grid()

sampled_acc = {}
sampled_fsha_acc = {}

for split in [2,3,4]:
    sampled_acc[split] = [sum(log_drive_dsa[split][:,1][i*log_freq:(i+1)*log_freq])/log_freq for i in range(int(len(log_drive_dsa[split][:,0])/log_freq))]
    sampled_fsha_acc[split] = [sum(log_drive_fsha[split][:,1][i*log_freq:(i+1)*log_freq])/log_freq for i in range(int(len(log_drive_fsha[split][:,0])/log_freq))]
ran = [i * log_freq + log_freq/2 for i in range(int(1000/log_freq))]
plt.ylabel('Training accuracy')
plt.xlabel('Iteration')
plt.plot(ran, sampled_acc[2], 'ro-', ran, sampled_acc[3], 'b^-', ran, sampled_acc[4], 'gs-', markevery=13)
plt.plot(ran, sampled_fsha_acc[2], 'ro:', ran, sampled_fsha_acc[3], 'b^:', ran, sampled_fsha_acc[4], 'gs:', markevery=13)
# ax2=plt.gca().twinx()
# ax2.plot(ran, sampled_acc[2], 'ro-', ran, sampled_acc[3], 'b^-', ran, sampled_acc[4], 'gs-', markevery=7)
plt.ylabel('Training accuracy')
plt.legend(["DSA ($h=2$)", "DSA ($h=3$)", "DSA ($h=4$)", "FSHA ($h=2$)", "FSHA ($h=3$)", "FSHA ($h=4$)"])
plt.savefig("fig/drive-acc.pdf", bbox_inches='tight')

# %%
split=4
drive_dsa_size = {}
log_drive_dsa_size = {}

make_f, make_g, make_e, make_d, make_c = mlp.make_mlp(attr_num=48, class_num=11, split=split, units=256, ed_act="sigmoid")

for size in [1,5,10,20,50]:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=size, random_state=42)
    
    target_ds = make_dataset(x_train, y_train, lambda t: t)
    aux_ds = make_dataset(x_test, y_test, lambda t: t)
    
    drive_dsa_size[size] = dsa(target_ds=target_ds, aux_ds=aux_ds)
    print("============================")
    print("======Auxiliary size is {}======".format(size))
    print("============================")
    log_drive_dsa_size[size] = drive_dsa_size[size].dsa_attack(
        make_f=make_f,
        make_g=make_g,
        lr=0.001,
        loss_fn=tf.keras.losses.SparseCategoricalCrossentropy(),
        acc_fn=tf.keras.metrics.SparseCategoricalAccuracy(),
        batch_size=32,
        iterations=1000,
        make_e=make_e,
        make_d=make_d,
        make_c=make_c,
        lr_e=0.001, # learning rate of the encoder/decoder/critic is set to be smaller
        lr_d=0.001,
        lr_c=0.001,
        verbose=True,
        log_freq=200)
# Out:
# ============================
# ======Auxiliary size is 1======
# ============================
# Iteration 200, train accuracy: 0.3218332969397306, average attack MSE: 0.019391184761188923
# Iteration 400, train accuracy: 0.47495907202363014, average attack MSE: 0.01662657999433577
# Iteration 600, train accuracy: 0.5640409809350967, average attack MSE: 0.016791286915540694
# Iteration 800, train accuracy: 0.6207993933558464, average attack MSE: 0.016391193387098612
# Iteration 1000, train accuracy: 0.6595360633730888, average attack MSE: 0.016581603209488094
# ============================
# ======Auxiliary size is 5======
# ============================
# Iteration 200, train accuracy: 0.31186243511736395, average attack MSE: 0.015302848899737001
# Iteration 400, train accuracy: 0.49146564304828644, average attack MSE: 0.012543014362454414
# Iteration 600, train accuracy: 0.5816616433858871, average attack MSE: 0.012830863846465946
# Iteration 800, train accuracy: 0.6367807695269585, average attack MSE: 0.012664799129124731
# Iteration 1000, train accuracy: 0.6700372165441513, average attack MSE: 0.012560910945758223
# ============================
# ======Auxiliary size is 10======
# ============================
# Iteration 200, train accuracy: 0.29542671009898186, average attack MSE: 0.013982664765790105
# Iteration 400, train accuracy: 0.46799569591879847, average attack MSE: 0.01152944538043812
# Iteration 600, train accuracy: 0.5663832020759583, average attack MSE: 0.01165659904712811
# Iteration 800, train accuracy: 0.6221622502803803, average attack MSE: 0.01160960185341537
# Iteration 1000, train accuracy: 0.6582725343108177, average attack MSE: 0.011723860914353281
# ============================
# ======Auxiliary size is 20======
# ============================
# Iteration 200, train accuracy: 0.3092962108552456, average attack MSE: 0.016002203542739152
# Iteration 400, train accuracy: 0.4505393327772617, average attack MSE: 0.012331098895519971
# Iteration 600, train accuracy: 0.5323723405599594, average attack MSE: 0.012415968948043882
# Iteration 800, train accuracy: 0.5992921993136406, average attack MSE: 0.012548992596566676
# Iteration 1000, train accuracy: 0.6421777459979058, average attack MSE: 0.012182432857807726
# ============================
# ======Auxiliary size is 50======
# ============================
# Iteration 200, train accuracy: 0.34726607080549, average attack MSE: 0.01496883793734014
# Iteration 400, train accuracy: 0.5013779103755951, average attack MSE: 0.011621538915205747
# Iteration 600, train accuracy: 0.5890875408053398, average attack MSE: 0.01153202427085489
# Iteration 800, train accuracy: 0.6424904751777649, average attack MSE: 0.011607959095854312
# Iteration 1000, train accuracy: 0.6748904919624329, average attack MSE: 0.01160503888502717

# %%
ran = ["1","5","10","20","50"]
rgn = [tf.keras.losses.MeanSquaredError()(np.random.normal(loc=0.5,scale=0.25,size=x.shape),x) for i in ran]
rgu = [tf.keras.losses.MeanSquaredError()(np.random.uniform(low=0,high=1,size=x.shape),x) for i in ran]
mse = [0.016581603209488094,0.012560910945758223,0.011723860914353281,0.012182432857807726,0.01160503888502717]
plt.yscale('logit')
plt.ylim([0.01,0.20])
plt.grid()
plt.yticks(ticks=[0.01,0.02,0.05,0.1,0.15,0.2],labels=["0.01","0.02","0.05","0.10","0.15","0.20"])
plt.plot(ran,rgu,'co-',ran,rgn,'mv-',ran,mse,'bs-', markevery=1)
plt.ylabel('MSE per feature')
plt.xlabel('Number of records in the auxiliary dataset')
plt.legend(["RG-uniform", "RG-normal", "DSA"])
plt.savefig("fig/drive-size.pdf", bbox_inches='tight')
