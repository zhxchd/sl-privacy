# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# %%
BUFFER_SIZE = 10000

def parseC(x):
    x = x / (255/2) - 1
    x = tf.clip_by_value(x, -1., 1.)
    return x

def make_dataset(X, Y, f):
    x = tf.data.Dataset.from_tensor_slices(X)
    y = tf.data.Dataset.from_tensor_slices(Y)
    x = x.map(f)
    xy = tf.data.Dataset.zip((x, y))
    xy = xy.shuffle(BUFFER_SIZE)
    return xy

def load_cifar10():
    cifar10 = tf.keras.datasets.cifar10
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train = x_train.astype(np.float32)
    x_test = x_test.astype(np.float32)
    
    xpriv = make_dataset(x_train, y_train, parseC)
    xpub = make_dataset(x_test, y_test, parseC)

    return xpriv, xpub

xpub, xpriv = load_cifar10()

# %%
batch_size = 64
id_setup = 4
lr_classify = 0.001
lr_encoder = 0.001
lr_decoder = 0.0001
lr_discriminator = 0.001
gradient_penalty = 500.

iterations = 2000
# log_frequency = 200

# %%
def ResBlock(inputs, dim, ks=3, bn=False, activation='relu', reduce=1):
    x = inputs
    
    stride = reduce
    
    if bn:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(dim, ks, stride, padding='same')(x)
    
    if bn:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(dim, ks, padding='same')(x)
    
    if reduce > 1:
        inputs = tf.keras.layers.Conv2D(dim, ks, stride, padding='same')(inputs)
    
    return inputs + x

def make_f(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    x = tf.keras.layers.Conv2D(64, 3, 1, padding='same')(xin)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(2)(x)
    x = ResBlock(x, 64)
    x = ResBlock(x, 128, reduce=2)
    x = ResBlock(x, 128)
    x = ResBlock(x, 256, reduce=2)
    return tf.keras.Model(xin, x)

def make_g(input_shape, class_num):
    xin = tf.keras.layers.Input(input_shape)
    x = xin
    x = ResBlock(xin, 256)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if class_num == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = class_num

    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(units, activation=activation)(x)
    return tf.keras.Model(xin, x)

def make_encoder(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    act = "relu"
    x = tf.keras.layers.Conv2D(64, 3, 2, padding='same', activation=act)(xin)
    x = tf.keras.layers.Conv2D(128, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2D(256, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2D(256, 3, 1, padding='same')(x)
    return tf.keras.Model(xin, x)

def make_decoder(input_shape, channels=3):
    xin = tf.keras.layers.Input(input_shape)
    act = None
    x = tf.keras.layers.Conv2DTranspose(256, 3, 2, padding='same', activation=act)(xin)
    x = tf.keras.layers.Conv2DTranspose(128, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2DTranspose(channels, 3, 2, padding='same', activation="tanh")(x)
    return tf.keras.Model(xin, x)

def make_generator(input_shape, channels=3):
    model = tf.keras.Sequential()
    model.add(layers.Dense(8*8*256, use_bias=False, input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((8, 8, 256)))
    assert model.output_shape == (None, 8, 8, 256)  # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 8, 8, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 16, 16, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(channels, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 32, 32, 3)

    return model

def make_discriminator(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    x = tf.keras.layers.Conv2D(256, 3, 1, padding='same')(xin)
    bn = False
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = tf.keras.layers.Conv2D(256, 3, 2, padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(xin, x)

# %%
def get_gradient_penalty(x, x_gen):
        epsilon = tf.random.uniform([x.shape[0], 1, 1, 1], 0.0, 1.0)
        x_hat = epsilon * x + (1 - epsilon) * x_gen
        with tf.GradientTape() as t:
            t.watch(x_hat)
            d_hat = discriminator(x_hat, training=True)
        gradients = t.gradient(d_hat, x_hat)
        ddx = tf.sqrt(tf.reduce_sum(gradients ** 2, axis=[1, 2]))
        d_regularizer = tf.reduce_mean((ddx - 1.0) ** 2)
        return d_regularizer

# %%
client_dataset = xpriv.batch(batch_size, drop_remainder=True).repeat(-1)
attacker_dataset = xpub.batch(batch_size, drop_remainder=True).repeat(-1)

input_shape = xpriv.element_spec[0].shape
f = make_f(input_shape)
intermidiate_shape = f.layers[-1].output_shape[1:]
g = make_g(input_shape=intermidiate_shape, class_num=10)
encoder = make_encoder(input_shape=input_shape)
generator = make_generator(input_shape=(4096,))
discriminator = make_discriminator(intermidiate_shape)

f_opt = tf.keras.optimizers.Adam(learning_rate=lr_classify)
encoder_opt = tf.keras.optimizers.Adam(learning_rate=lr_encoder)
decoder_opt = tf.keras.optimizers.Adam(learning_rate=lr_decoder)
discriminator_opt = tf.keras.optimizers.Adam(learning_rate=lr_discriminator)

iterator = zip(client_dataset.take(iterations), attacker_dataset.take(iterations))

iter = 1
log = []

for (x_private, label_private), (x_public, label_public) in iterator:
    with tf.GradientTape(persistent=True) as tape:
        z_private = f(x_private, training=True)
        y_pred = g(z_private, training=True)
        c_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=label_private, y_pred=y_pred)

        z_public = encoder(x_public, training=True)

        d_privite_logits = discriminator(z_private, training=True)
        d_public_logits = discriminator(z_public, training=True)

        encoder_loss = -tf.reduce_mean(d_public_logits)

        d_loss = tf.reduce_mean( d_public_logits ) - tf.reduce_mean( d_privite_logits )
        w = float(gradient_penalty)
        gp = get_gradient_penalty(z_private, z_public)
        d_loss += gp * w

    # update f and g:
    var = f.trainable_variables + g.trainable_variables
    gradients = tape.gradient(c_loss, var)
    f_opt.apply_gradients(zip(gradients, var))

    # encoder is updated by f_loss
    var = encoder.trainable_variables
    gradients = tape.gradient(encoder_loss, var)
    encoder_opt.apply_gradients(zip(gradients, var))

    # update discriminator:
    var = discriminator.trainable_variables
    gradients = tape.gradient(d_loss, var)
    discriminator_opt.apply_gradients(zip(gradients, var))

    # Now let's do something with the generatative decoder:
    flat_z_pub = f(x_public, training=False).numpy().reshape((batch_size, 4096))
    for _ in range(20):
        with tf.GradientTape() as tape:
            # x_temp = generator(tf.concat([flat_z_pub, tf.constant(np.random.rand(*(flat_z_pub.shape)).astype("float32"))],1), training=True)
            x_temp = generator(flat_z_pub)
            generator_loss = tf.losses.MeanSquaredError()(x_public, x_temp)
        var = generator.trainable_variables
        gradients = tape.gradient(generator_loss, var)
        decoder_opt.apply_gradients(zip(gradients, var))
    
    # Now we have the generative decoder trained, let's attack original image
    flat_z_priv = z_private.numpy().reshape((batch_size, 4096))
    # rec_x_private = generator(tf.concat([flat_z_priv, tf.constant(np.random.rand(*(flat_z_priv.shape)).astype("float32"))],1), training=True)
    rec_x_private = generator(flat_z_priv, training=False)
    loss_verification = tf.losses.MeanSquaredError()(x_private, rec_x_private)
    log.append(loss_verification)
    print("Iteration {} attack MSE: {}".format(iter, loss_verification.numpy()))
    iter += 1
# Out:
# Iteration 1 attack MSE: 0.37903326749801636
# Iteration 2 attack MSE: 0.40188074111938477
# Iteration 3 attack MSE: 0.40537506341934204
# Iteration 4 attack MSE: 0.42307278513908386
# Iteration 5 attack MSE: 0.4222213327884674
# Iteration 6 attack MSE: 0.38904792070388794
# Iteration 7 attack MSE: 0.3667060434818268
# Iteration 8 attack MSE: 0.39554107189178467
# Iteration 9 attack MSE: 0.36659494042396545
# Iteration 10 attack MSE: 0.3750048279762268
# Iteration 11 attack MSE: 0.39454400539398193
# Iteration 12 attack MSE: 0.3563322424888611
# Iteration 13 attack MSE: 0.35109370946884155
# Iteration 14 attack MSE: 0.3478296399116516
# Iteration 15 attack MSE: 0.3543969392776489
# Iteration 16 attack MSE: 0.3702244162559509
# Iteration 17 attack MSE: 0.3595469295978546
# Iteration 18 attack MSE: 0.3663645088672638
# Iteration 19 attack MSE: 0.36074885725975037
# Iteration 20 attack MSE: 0.3611014783382416
# Iteration 21 attack MSE: 0.3659592866897583
# Iteration 22 attack MSE: 0.3658659756183624
# Iteration 23 attack MSE: 0.3704909086227417
# Iteration 24 attack MSE: 0.35633888840675354
# Iteration 25 attack MSE: 0.3787071704864502
# Iteration 26 attack MSE: 0.38861504197120667
# Iteration 27 attack MSE: 0.37073951959609985
# Iteration 28 attack MSE: 0.3446175456047058
# Iteration 29 attack MSE: 0.3458467125892639
# Iteration 30 attack MSE: 0.35040760040283203
# Iteration 31 attack MSE: 0.36250871419906616
# Iteration 32 attack MSE: 0.3489082455635071
# Iteration 33 attack MSE: 0.3649834394454956
# Iteration 34 attack MSE: 0.3645585775375366
# Iteration 35 attack MSE: 0.33594080805778503
# Iteration 36 attack MSE: 0.3844270408153534
# Iteration 37 attack MSE: 0.3380163311958313
# Iteration 38 attack MSE: 0.37840431928634644
# Iteration 39 attack MSE: 0.3546806573867798
# Iteration 40 attack MSE: 0.3324851393699646
# Iteration 41 attack MSE: 0.3319174647331238
# Iteration 42 attack MSE: 0.31807124614715576
# Iteration 43 attack MSE: 0.321239709854126
# Iteration 44 attack MSE: 0.3389640152454376
# Iteration 45 attack MSE: 0.3488403260707855
# Iteration 46 attack MSE: 0.3284698724746704
# Iteration 47 attack MSE: 0.31990236043930054
# Iteration 48 attack MSE: 0.2971542477607727
# Iteration 49 attack MSE: 0.3043023943901062
# Iteration 50 attack MSE: 0.2976205050945282
# Iteration 51 attack MSE: 0.3064064383506775
# Iteration 52 attack MSE: 0.30928266048431396
# Iteration 53 attack MSE: 0.3156065344810486
# Iteration 54 attack MSE: 0.30376914143562317
# Iteration 55 attack MSE: 0.3119966685771942
# Iteration 56 attack MSE: 0.30788689851760864
# Iteration 57 attack MSE: 0.30997103452682495
# Iteration 58 attack MSE: 0.2947778105735779
# Iteration 59 attack MSE: 0.3075082004070282
# Iteration 60 attack MSE: 0.2974800169467926
# Iteration 61 attack MSE: 0.293851375579834
# Iteration 62 attack MSE: 0.3134082555770874
# Iteration 63 attack MSE: 0.3152070939540863
# Iteration 64 attack MSE: 0.30211305618286133
# Iteration 65 attack MSE: 0.29444223642349243
# Iteration 66 attack MSE: 0.28891652822494507
# Iteration 67 attack MSE: 0.2881777882575989
# Iteration 68 attack MSE: 0.29375046491622925
# Iteration 69 attack MSE: 0.29389169812202454
# Iteration 70 attack MSE: 0.2826872169971466
# Iteration 71 attack MSE: 0.2996833622455597
# Iteration 72 attack MSE: 0.3099498152732849
# Iteration 73 attack MSE: 0.29820531606674194
# Iteration 74 attack MSE: 0.28705933690071106
# Iteration 75 attack MSE: 0.26981884241104126
# Iteration 76 attack MSE: 0.29921621084213257
# Iteration 77 attack MSE: 0.2837112843990326
# Iteration 78 attack MSE: 0.3192805051803589
# Iteration 79 attack MSE: 0.28719210624694824
# Iteration 80 attack MSE: 0.2955981492996216
# Iteration 81 attack MSE: 0.3154163360595703
# Iteration 82 attack MSE: 0.27595996856689453
# Iteration 83 attack MSE: 0.27281221747398376
# Iteration 84 attack MSE: 0.2751502990722656
# Iteration 85 attack MSE: 0.2899266481399536
# Iteration 86 attack MSE: 0.29961228370666504
# Iteration 87 attack MSE: 0.26545456051826477
# Iteration 88 attack MSE: 0.2647790014743805
# Iteration 89 attack MSE: 0.2924378514289856
# Iteration 90 attack MSE: 0.3110874891281128
# Iteration 91 attack MSE: 0.2781628668308258
# Iteration 92 attack MSE: 0.26803022623062134
# Iteration 93 attack MSE: 0.2604164779186249
# Iteration 94 attack MSE: 0.26282110810279846
# Iteration 95 attack MSE: 0.25091734528541565
# Iteration 96 attack MSE: 0.25390860438346863
# Iteration 97 attack MSE: 0.2552294135093689
# Iteration 98 attack MSE: 0.2551683187484741
# Iteration 99 attack MSE: 0.2555396258831024
# Iteration 100 attack MSE: 0.26669734716415405
# Iteration 101 attack MSE: 0.2534552812576294
# Iteration 102 attack MSE: 0.2547846734523773
# Iteration 103 attack MSE: 0.24551813304424286
# Iteration 104 attack MSE: 0.23589636385440826
# Iteration 105 attack MSE: 0.2508319020271301
# Iteration 106 attack MSE: 0.25048723816871643
# Iteration 107 attack MSE: 0.25617456436157227
# Iteration 108 attack MSE: 0.24342674016952515
# Iteration 109 attack MSE: 0.21748268604278564
# Iteration 110 attack MSE: 0.23045173287391663
# Iteration 111 attack MSE: 0.2599320113658905
# Iteration 112 attack MSE: 0.21947823464870453
# Iteration 113 attack MSE: 0.2621651291847229
# Iteration 114 attack MSE: 0.24293917417526245
# Iteration 115 attack MSE: 0.2692216634750366
# Iteration 116 attack MSE: 0.2516559660434723
# Iteration 117 attack MSE: 0.23504284024238586
# Iteration 118 attack MSE: 0.24003252387046814
# Iteration 119 attack MSE: 0.24662570655345917
# Iteration 120 attack MSE: 0.25309163331985474
# Iteration 121 attack MSE: 0.23277345299720764
# Iteration 122 attack MSE: 0.2253505140542984
# Iteration 123 attack MSE: 0.215457022190094
# Iteration 124 attack MSE: 0.21846593916416168
# Iteration 125 attack MSE: 0.23155330121517181
# Iteration 126 attack MSE: 0.23322339355945587
# Iteration 127 attack MSE: 0.22679226100444794
# Iteration 128 attack MSE: 0.22712934017181396
# Iteration 129 attack MSE: 0.23068375885486603
# Iteration 130 attack MSE: 0.22816139459609985
# Iteration 131 attack MSE: 0.21070218086242676
# Iteration 132 attack MSE: 0.21268126368522644
# Iteration 133 attack MSE: 0.21358689665794373
# Iteration 134 attack MSE: 0.20106647908687592
# Iteration 135 attack MSE: 0.2059168666601181
# Iteration 136 attack MSE: 0.19089743494987488
# Iteration 137 attack MSE: 0.2004082202911377
# Iteration 138 attack MSE: 0.2168019413948059
# Iteration 139 attack MSE: 0.19237323105335236
# Iteration 140 attack MSE: 0.2253189980983734
# Iteration 141 attack MSE: 0.2207738310098648
# Iteration 142 attack MSE: 0.21053576469421387
# Iteration 143 attack MSE: 0.1998482644557953
# Iteration 144 attack MSE: 0.22593213617801666
# Iteration 145 attack MSE: 0.22167278826236725
# Iteration 146 attack MSE: 0.20552043616771698
# Iteration 147 attack MSE: 0.20165207982063293
# Iteration 148 attack MSE: 0.22521832585334778
# Iteration 149 attack MSE: 0.20695751905441284
# Iteration 150 attack MSE: 0.20187240839004517
# Iteration 151 attack MSE: 0.2187492847442627
# Iteration 152 attack MSE: 0.2171977162361145
# Iteration 153 attack MSE: 0.19693556427955627
# Iteration 154 attack MSE: 0.20115837454795837
# Iteration 155 attack MSE: 0.19036728143692017
# Iteration 156 attack MSE: 0.20432105660438538
# Iteration 157 attack MSE: 0.2039642482995987
# Iteration 158 attack MSE: 0.17814770340919495
# Iteration 159 attack MSE: 0.18585552275180817
# Iteration 160 attack MSE: 0.1866682767868042
# Iteration 161 attack MSE: 0.18661576509475708
# Iteration 162 attack MSE: 0.16656279563903809
# Iteration 163 attack MSE: 0.18083947896957397
# Iteration 164 attack MSE: 0.1733018308877945
# Iteration 165 attack MSE: 0.17509868741035461
# Iteration 166 attack MSE: 0.1695917844772339
# Iteration 167 attack MSE: 0.1666073501110077
# Iteration 168 attack MSE: 0.18085084855556488
# Iteration 169 attack MSE: 0.15686693787574768
# Iteration 170 attack MSE: 0.15048959851264954
# Iteration 171 attack MSE: 0.1621282994747162
# Iteration 172 attack MSE: 0.15806400775909424
# Iteration 173 attack MSE: 0.1516825556755066
# Iteration 174 attack MSE: 0.15709732472896576
# Iteration 175 attack MSE: 0.17514081299304962
# Iteration 176 attack MSE: 0.15366141498088837
# Iteration 177 attack MSE: 0.15151599049568176
# Iteration 178 attack MSE: 0.14856594800949097
# Iteration 179 attack MSE: 0.15336468815803528
# Iteration 180 attack MSE: 0.15322163701057434
# Iteration 181 attack MSE: 0.14526022970676422
# Iteration 182 attack MSE: 0.1430220901966095
# Iteration 183 attack MSE: 0.1433258056640625
# Iteration 184 attack MSE: 0.14014677703380585
# Iteration 185 attack MSE: 0.13663426041603088
# Iteration 186 attack MSE: 0.14904366433620453
# Iteration 187 attack MSE: 0.1450476348400116
# Iteration 188 attack MSE: 0.14761105179786682
# Iteration 189 attack MSE: 0.16477200388908386
# Iteration 190 attack MSE: 0.14866414666175842
# Iteration 191 attack MSE: 0.16433949768543243
# Iteration 192 attack MSE: 0.15418532490730286
# Iteration 193 attack MSE: 0.14160457253456116
# Iteration 194 attack MSE: 0.13888007402420044
# Iteration 195 attack MSE: 0.1505712866783142
# Iteration 196 attack MSE: 0.15539951622486115
# Iteration 197 attack MSE: 0.14348849654197693
# Iteration 198 attack MSE: 0.14651109278202057
# Iteration 199 attack MSE: 0.15803390741348267
# Iteration 200 attack MSE: 0.1563372015953064
# Iteration 201 attack MSE: 0.14960351586341858
# Iteration 202 attack MSE: 0.13706889748573303
# Iteration 203 attack MSE: 0.1377437710762024
# Iteration 204 attack MSE: 0.13992732763290405
# Iteration 205 attack MSE: 0.13607937097549438
# Iteration 206 attack MSE: 0.13552403450012207
# Iteration 207 attack MSE: 0.14204494655132294
# Iteration 208 attack MSE: 0.14626550674438477
# Iteration 209 attack MSE: 0.1381542980670929
# Iteration 210 attack MSE: 0.13159754872322083
# Iteration 211 attack MSE: 0.1452440768480301
# Iteration 212 attack MSE: 0.129623144865036
# Iteration 213 attack MSE: 0.13518410921096802
# Iteration 214 attack MSE: 0.1264795958995819
# Iteration 215 attack MSE: 0.1322987824678421
# Iteration 216 attack MSE: 0.1316162496805191
# Iteration 217 attack MSE: 0.1244216188788414
# Iteration 218 attack MSE: 0.13272631168365479
# Iteration 219 attack MSE: 0.13312113285064697
# Iteration 220 attack MSE: 0.11673503369092941
# Iteration 221 attack MSE: 0.12102542817592621
# Iteration 222 attack MSE: 0.12584218382835388
# Iteration 223 attack MSE: 0.11882668733596802
# Iteration 224 attack MSE: 0.11477945744991302
# Iteration 225 attack MSE: 0.12519600987434387
# Iteration 226 attack MSE: 0.1260574907064438
# Iteration 227 attack MSE: 0.12737087905406952
# Iteration 228 attack MSE: 0.12472555041313171
# Iteration 229 attack MSE: 0.1174876019358635
# Iteration 230 attack MSE: 0.11178422719240189
# Iteration 231 attack MSE: 0.1239880695939064
# Iteration 232 attack MSE: 0.106393963098526
# Iteration 233 attack MSE: 0.10102415084838867
# Iteration 234 attack MSE: 0.11480556428432465
# Iteration 235 attack MSE: 0.10654957592487335
# Iteration 236 attack MSE: 0.11092845350503922
# Iteration 237 attack MSE: 0.10661397874355316
# Iteration 238 attack MSE: 0.11337250471115112
# Iteration 239 attack MSE: 0.11407888680696487
# Iteration 240 attack MSE: 0.10689613223075867
# Iteration 241 attack MSE: 0.11349369585514069
# Iteration 242 attack MSE: 0.10783001780509949
# Iteration 243 attack MSE: 0.11283187568187714
# Iteration 244 attack MSE: 0.10208840668201447
# Iteration 245 attack MSE: 0.11129112541675568
# Iteration 246 attack MSE: 0.1114896908402443
# Iteration 247 attack MSE: 0.11708857119083405
# Iteration 248 attack MSE: 0.10659588128328323
# Iteration 249 attack MSE: 0.10388170182704926
# Iteration 250 attack MSE: 0.1061689704656601
# Iteration 251 attack MSE: 0.11430254578590393
# Iteration 252 attack MSE: 0.09395943582057953
# Iteration 253 attack MSE: 0.11244703829288483
# Iteration 254 attack MSE: 0.09550753235816956
# Iteration 255 attack MSE: 0.10723237693309784
# Iteration 256 attack MSE: 0.10931607335805893
# Iteration 257 attack MSE: 0.10477002710103989
# Iteration 258 attack MSE: 0.11098863184452057
# Iteration 259 attack MSE: 0.10313974320888519
# Iteration 260 attack MSE: 0.09491879492998123
# Iteration 261 attack MSE: 0.10193730890750885
# Iteration 262 attack MSE: 0.10940168797969818
# Iteration 263 attack MSE: 0.11044225096702576
# Iteration 264 attack MSE: 0.1516619771718979
# Iteration 265 attack MSE: 0.10275448113679886
# Iteration 266 attack MSE: 0.10096529126167297
# Iteration 267 attack MSE: 0.1069076657295227
# Iteration 268 attack MSE: 0.10454323142766953
# Iteration 269 attack MSE: 0.10274209082126617
# Iteration 270 attack MSE: 0.10064488649368286
# Iteration 271 attack MSE: 0.10370203852653503
# Iteration 272 attack MSE: 0.0907592624425888
# Iteration 273 attack MSE: 0.0884651243686676
# Iteration 274 attack MSE: 0.09440723061561584
# Iteration 275 attack MSE: 0.09868301451206207
# Iteration 276 attack MSE: 0.09891071915626526
# Iteration 277 attack MSE: 0.0997588112950325
# Iteration 278 attack MSE: 0.10275670886039734
# Iteration 279 attack MSE: 0.09801784157752991
# Iteration 280 attack MSE: 0.09873022139072418
# Iteration 281 attack MSE: 0.09626942873001099
# Iteration 282 attack MSE: 0.09970040619373322
# Iteration 283 attack MSE: 0.09495055675506592
# Iteration 284 attack MSE: 0.10095946490764618
# Iteration 285 attack MSE: 0.09877528250217438
# Iteration 286 attack MSE: 0.09075646102428436
# Iteration 287 attack MSE: 0.10605045408010483
# Iteration 288 attack MSE: 0.09292809665203094
# Iteration 289 attack MSE: 0.09154210239648819
# Iteration 290 attack MSE: 0.09892645478248596
# Iteration 291 attack MSE: 0.09222190082073212
# Iteration 292 attack MSE: 0.07787784934043884
# Iteration 293 attack MSE: 0.09084315598011017
# Iteration 294 attack MSE: 0.08646631240844727
# Iteration 295 attack MSE: 0.07662729918956757
# Iteration 296 attack MSE: 0.08876240998506546
# Iteration 297 attack MSE: 0.08636701107025146
# Iteration 298 attack MSE: 0.09399844706058502
# Iteration 299 attack MSE: 0.09710417687892914
# Iteration 300 attack MSE: 0.09345616400241852
# Iteration 301 attack MSE: 0.09157581627368927
# Iteration 302 attack MSE: 0.09389632940292358
# Iteration 303 attack MSE: 0.09553806483745575
# Iteration 304 attack MSE: 0.08987411856651306
# Iteration 305 attack MSE: 0.08503700792789459
# Iteration 306 attack MSE: 0.08839122205972672
# Iteration 307 attack MSE: 0.09002862870693207
# Iteration 308 attack MSE: 0.08466000854969025
# Iteration 309 attack MSE: 0.0785692036151886
# Iteration 310 attack MSE: 0.07814556360244751
# Iteration 311 attack MSE: 0.07875462621450424
# Iteration 312 attack MSE: 0.07626594603061676
# Iteration 313 attack MSE: 0.07688811421394348
# Iteration 314 attack MSE: 0.0821785181760788
# Iteration 315 attack MSE: 0.07426829636096954
# Iteration 316 attack MSE: 0.07405032217502594
# Iteration 317 attack MSE: 0.07756989449262619
# Iteration 318 attack MSE: 0.07250895351171494
# Iteration 319 attack MSE: 0.07078934460878372
# Iteration 320 attack MSE: 0.07889141142368317
# Iteration 321 attack MSE: 0.07215330004692078
# Iteration 322 attack MSE: 0.0710039734840393
# Iteration 323 attack MSE: 0.07217159867286682
# Iteration 324 attack MSE: 0.0746774971485138
# Iteration 325 attack MSE: 0.07210376858711243
# Iteration 326 attack MSE: 0.07219541072845459
# Iteration 327 attack MSE: 0.06910990923643112
# Iteration 328 attack MSE: 0.07399725914001465
# Iteration 329 attack MSE: 0.0680452361702919
# Iteration 330 attack MSE: 0.06894547492265701
# Iteration 331 attack MSE: 0.06361031532287598
# Iteration 332 attack MSE: 0.0658685714006424
# Iteration 333 attack MSE: 0.07072296738624573
# Iteration 334 attack MSE: 0.0646379292011261
# Iteration 335 attack MSE: 0.06789389997720718
# Iteration 336 attack MSE: 0.06908667087554932
# Iteration 337 attack MSE: 0.06666192412376404
# Iteration 338 attack MSE: 0.06354707479476929
# Iteration 339 attack MSE: 0.06554417312145233
# Iteration 340 attack MSE: 0.06401318311691284
# Iteration 341 attack MSE: 0.06984780728816986
# Iteration 342 attack MSE: 0.06784951686859131
# Iteration 343 attack MSE: 0.08198478817939758
# Iteration 344 attack MSE: 0.06625919044017792
# Iteration 345 attack MSE: 0.06819048523902893
# Iteration 346 attack MSE: 0.07046176493167877
# Iteration 347 attack MSE: 0.06793676316738129
# Iteration 348 attack MSE: 0.06770732253789902
# Iteration 349 attack MSE: 0.06551453471183777
# Iteration 350 attack MSE: 0.06511580944061279
# Iteration 351 attack MSE: 0.06428453326225281
# Iteration 352 attack MSE: 0.07113855332136154
# Iteration 353 attack MSE: 0.06461440026760101
# Iteration 354 attack MSE: 0.06495142728090286
# Iteration 355 attack MSE: 0.06017934903502464
# Iteration 356 attack MSE: 0.05836830288171768
# Iteration 357 attack MSE: 0.05686211585998535
# Iteration 358 attack MSE: 0.05672421306371689
# Iteration 359 attack MSE: 0.058142583817243576
# Iteration 360 attack MSE: 0.056443244218826294
# Iteration 361 attack MSE: 0.054470669478178024
# Iteration 362 attack MSE: 0.058269888162612915
# Iteration 363 attack MSE: 0.05579697713255882
# Iteration 364 attack MSE: 0.060902707278728485
# Iteration 365 attack MSE: 0.06405507773160934
# Iteration 366 attack MSE: 0.05898574739694595
# Iteration 367 attack MSE: 0.07274984568357468
# Iteration 368 attack MSE: 0.06613407284021378
# Iteration 369 attack MSE: 0.0631672739982605
# Iteration 370 attack MSE: 0.06422542780637741
# Iteration 371 attack MSE: 0.0649842768907547
# Iteration 372 attack MSE: 0.08953661471605301
# Iteration 373 attack MSE: 0.06820184737443924
# Iteration 374 attack MSE: 0.06419506669044495
# Iteration 375 attack MSE: 0.06675782799720764
# Iteration 376 attack MSE: 0.06391532719135284
# Iteration 377 attack MSE: 0.06039256975054741
# Iteration 378 attack MSE: 0.059030309319496155
# Iteration 379 attack MSE: 0.06216411665081978
# Iteration 380 attack MSE: 0.058267004787921906
# Iteration 381 attack MSE: 0.06261560320854187
# Iteration 382 attack MSE: 0.06144396588206291
# Iteration 383 attack MSE: 0.06271593272686005
# Iteration 384 attack MSE: 0.05686154216527939
# Iteration 385 attack MSE: 0.05915325507521629
# Iteration 386 attack MSE: 0.05146784335374832
# Iteration 387 attack MSE: 0.061626024544239044
# Iteration 388 attack MSE: 0.05467098206281662
# Iteration 389 attack MSE: 0.05340828746557236
# Iteration 390 attack MSE: 0.06185319274663925
# Iteration 391 attack MSE: 0.05904902517795563
# Iteration 392 attack MSE: 0.052903108298778534
# Iteration 393 attack MSE: 0.05841158330440521
# Iteration 394 attack MSE: 0.05429879203438759
# Iteration 395 attack MSE: 0.05756831169128418
# Iteration 396 attack MSE: 0.05790576711297035
# Iteration 397 attack MSE: 0.05689782649278641
# Iteration 398 attack MSE: 0.059417419135570526
# Iteration 399 attack MSE: 0.0622938796877861
# Iteration 400 attack MSE: 0.05942382663488388
# Iteration 401 attack MSE: 0.05688285827636719
# Iteration 402 attack MSE: 0.0578753724694252
# Iteration 403 attack MSE: 0.05861357972025871
# Iteration 404 attack MSE: 0.058569639921188354
# Iteration 405 attack MSE: 0.05624963343143463
# Iteration 406 attack MSE: 0.055151745676994324
# Iteration 407 attack MSE: 0.05670307204127312
# Iteration 408 attack MSE: 0.059935107827186584
# Iteration 409 attack MSE: 0.06525570154190063
# Iteration 410 attack MSE: 0.06195878982543945
# Iteration 411 attack MSE: 0.05696829780936241
# Iteration 412 attack MSE: 0.059857502579689026
# Iteration 413 attack MSE: 0.05564093589782715
# Iteration 414 attack MSE: 0.0608467236161232
# Iteration 415 attack MSE: 0.06153704971075058
# Iteration 416 attack MSE: 0.05620507150888443
# Iteration 417 attack MSE: 0.05176515877246857
# Iteration 418 attack MSE: 0.05264405161142349
# Iteration 419 attack MSE: 0.06249668821692467
# Iteration 420 attack MSE: 0.057125117629766464
# Iteration 421 attack MSE: 0.0568130761384964
# Iteration 422 attack MSE: 0.05800023674964905
# Iteration 423 attack MSE: 0.06208908557891846
# Iteration 424 attack MSE: 0.0581340417265892
# Iteration 425 attack MSE: 0.05408085882663727
# Iteration 426 attack MSE: 0.05627046152949333
# Iteration 427 attack MSE: 0.057472918182611465
# Iteration 428 attack MSE: 0.05432933196425438
# Iteration 429 attack MSE: 0.05464218184351921
# Iteration 430 attack MSE: 0.05484863743185997
# Iteration 431 attack MSE: 0.05430402606725693
# Iteration 432 attack MSE: 0.05424066632986069
# Iteration 433 attack MSE: 0.05332646146416664
# Iteration 434 attack MSE: 0.050622016191482544
# Iteration 435 attack MSE: 0.0529036745429039
# Iteration 436 attack MSE: 0.05536223202943802
# Iteration 437 attack MSE: 0.05377519130706787
# Iteration 438 attack MSE: 0.0548575222492218
# Iteration 439 attack MSE: 0.061095841228961945
# Iteration 440 attack MSE: 0.05264877527952194
# Iteration 441 attack MSE: 0.05871155485510826
# Iteration 442 attack MSE: 0.05582888424396515
# Iteration 443 attack MSE: 0.05024717003107071
# Iteration 444 attack MSE: 0.05838151276111603
# Iteration 445 attack MSE: 0.05892390012741089
# Iteration 446 attack MSE: 0.06192222982645035
# Iteration 447 attack MSE: 0.06005442515015602
# Iteration 448 attack MSE: 0.058414261788129807
# Iteration 449 attack MSE: 0.056813329458236694
# Iteration 450 attack MSE: 0.0562574528157711
# Iteration 451 attack MSE: 0.05373803526163101
# Iteration 452 attack MSE: 0.06129084900021553
# Iteration 453 attack MSE: 0.05657423287630081
# Iteration 454 attack MSE: 0.06493515521287918
# Iteration 455 attack MSE: 0.054431937634944916
# Iteration 456 attack MSE: 0.055144861340522766
# Iteration 457 attack MSE: 0.05157415196299553
# Iteration 458 attack MSE: 0.05413941293954849
# Iteration 459 attack MSE: 0.05418889969587326
# Iteration 460 attack MSE: 0.06705039739608765
# Iteration 461 attack MSE: 0.05269915238022804
# Iteration 462 attack MSE: 0.05109921470284462
# Iteration 463 attack MSE: 0.050167396664619446
# Iteration 464 attack MSE: 0.052004002034664154
# Iteration 465 attack MSE: 0.0461566299200058
# Iteration 466 attack MSE: 0.05329515412449837
# Iteration 467 attack MSE: 0.050913918763399124
# Iteration 468 attack MSE: 0.05383903905749321
# Iteration 469 attack MSE: 0.048335086554288864
# Iteration 470 attack MSE: 0.052278243005275726
# Iteration 471 attack MSE: 0.05152079835534096
# Iteration 472 attack MSE: 0.0515567846596241
# Iteration 473 attack MSE: 0.056082773953676224
# Iteration 474 attack MSE: 0.050600629299879074
# Iteration 475 attack MSE: 0.05508440360426903
# Iteration 476 attack MSE: 0.05031653121113777
# Iteration 477 attack MSE: 0.05701254680752754
# Iteration 478 attack MSE: 0.04706081748008728
# Iteration 479 attack MSE: 0.056137412786483765
# Iteration 480 attack MSE: 0.053158655762672424
# Iteration 481 attack MSE: 0.0514167845249176
# Iteration 482 attack MSE: 0.055474065244197845
# Iteration 483 attack MSE: 0.05661745369434357
# Iteration 484 attack MSE: 0.05274627357721329
# Iteration 485 attack MSE: 0.051774583756923676
# Iteration 486 attack MSE: 0.051078297197818756
# Iteration 487 attack MSE: 0.04694155231118202
# Iteration 488 attack MSE: 0.04378177970647812
# Iteration 489 attack MSE: 0.04568905383348465
# Iteration 490 attack MSE: 0.047424666583538055
# Iteration 491 attack MSE: 0.04873510077595711
# Iteration 492 attack MSE: 0.04090825095772743
# Iteration 493 attack MSE: 0.04454033449292183
# Iteration 494 attack MSE: 0.04448634386062622
# Iteration 495 attack MSE: 0.04694787412881851
# Iteration 496 attack MSE: 0.04751789569854736
# Iteration 497 attack MSE: 0.042990878224372864
# Iteration 498 attack MSE: 0.045432381331920624
# Iteration 499 attack MSE: 0.04065685719251633
# Iteration 500 attack MSE: 0.041787516325712204
# Iteration 501 attack MSE: 0.039398014545440674
# Iteration 502 attack MSE: 0.03900036960840225
# Iteration 503 attack MSE: 0.03887564688920975
# Iteration 504 attack MSE: 0.04090988636016846
# Iteration 505 attack MSE: 0.0386107861995697
# Iteration 506 attack MSE: 0.042734451591968536
# Iteration 507 attack MSE: 0.03986715152859688
# Iteration 508 attack MSE: 0.04072374477982521
# Iteration 509 attack MSE: 0.04174770787358284
# Iteration 510 attack MSE: 0.0426875539124012
# Iteration 511 attack MSE: 0.04214124381542206
# Iteration 512 attack MSE: 0.03834473714232445
# Iteration 513 attack MSE: 0.036854855716228485
# Iteration 514 attack MSE: 0.04201962798833847
# Iteration 515 attack MSE: 0.0376536101102829
# Iteration 516 attack MSE: 0.036142028868198395
# Iteration 517 attack MSE: 0.04104212671518326
# Iteration 518 attack MSE: 0.040546707808971405
# Iteration 519 attack MSE: 0.03861219435930252
# Iteration 520 attack MSE: 0.03784451261162758
# Iteration 521 attack MSE: 0.04312445968389511
# Iteration 522 attack MSE: 0.04091197997331619
# Iteration 523 attack MSE: 0.04132653772830963
# Iteration 524 attack MSE: 0.04204434156417847
# Iteration 525 attack MSE: 0.039860546588897705
# Iteration 526 attack MSE: 0.0429142564535141
# Iteration 527 attack MSE: 0.040674224495887756
# Iteration 528 attack MSE: 0.03922256827354431
# Iteration 529 attack MSE: 0.042895760387182236
# Iteration 530 attack MSE: 0.04061757028102875
# Iteration 531 attack MSE: 0.04492238536477089
# Iteration 532 attack MSE: 0.04008802771568298
# Iteration 533 attack MSE: 0.04072440415620804
# Iteration 534 attack MSE: 0.04497523233294487
# Iteration 535 attack MSE: 0.04425342381000519
# Iteration 536 attack MSE: 0.04148808866739273
# Iteration 537 attack MSE: 0.03788341209292412
# Iteration 538 attack MSE: 0.045184940099716187
# Iteration 539 attack MSE: 0.040109291672706604
# Iteration 540 attack MSE: 0.04186210408806801
# Iteration 541 attack MSE: 0.040142543613910675
# Iteration 542 attack MSE: 0.03857719153165817
# Iteration 543 attack MSE: 0.04077403247356415
# Iteration 544 attack MSE: 0.03892180323600769
# Iteration 545 attack MSE: 0.04140825569629669
# Iteration 546 attack MSE: 0.041248105466365814
# Iteration 547 attack MSE: 0.039811871945858
# Iteration 548 attack MSE: 0.04095662385225296
# Iteration 549 attack MSE: 0.04035710170865059
# Iteration 550 attack MSE: 0.039854735136032104
# Iteration 551 attack MSE: 0.04121603071689606
# Iteration 552 attack MSE: 0.04438353702425957
# Iteration 553 attack MSE: 0.040722623467445374
# Iteration 554 attack MSE: 0.042605675756931305
# Iteration 555 attack MSE: 0.038800064474344254
# Iteration 556 attack MSE: 0.04153631627559662
# Iteration 557 attack MSE: 0.04055739939212799
# Iteration 558 attack MSE: 0.042967479676008224
# Iteration 559 attack MSE: 0.042338766157627106
# Iteration 560 attack MSE: 0.04635205864906311
# Iteration 561 attack MSE: 0.0428423136472702
# Iteration 562 attack MSE: 0.04297082871198654
# Iteration 563 attack MSE: 0.04783192276954651
# Iteration 564 attack MSE: 0.03892643749713898
# Iteration 565 attack MSE: 0.04425886273384094
# Iteration 566 attack MSE: 0.04242754727602005
# Iteration 567 attack MSE: 0.04017753154039383
# Iteration 568 attack MSE: 0.03648952394723892
# Iteration 569 attack MSE: 0.04262644052505493
# Iteration 570 attack MSE: 0.04392439126968384
# Iteration 571 attack MSE: 0.043625783175230026
# Iteration 572 attack MSE: 0.03875859081745148
# Iteration 573 attack MSE: 0.041291333734989166
# Iteration 574 attack MSE: 0.04520012438297272
# Iteration 575 attack MSE: 0.03961877524852753
# Iteration 576 attack MSE: 0.056238722056150436
# Iteration 577 attack MSE: 0.03800146281719208
# Iteration 578 attack MSE: 0.041244640946388245
# Iteration 579 attack MSE: 0.04164545238018036
# Iteration 580 attack MSE: 0.035784415900707245
# Iteration 581 attack MSE: 0.03717431053519249
# Iteration 582 attack MSE: 0.03945743292570114
# Iteration 583 attack MSE: 0.03822580724954605
# Iteration 584 attack MSE: 0.04102427139878273
# Iteration 585 attack MSE: 0.03897516429424286
# Iteration 586 attack MSE: 0.036463961005210876
# Iteration 587 attack MSE: 0.04082858934998512
# Iteration 588 attack MSE: 0.03889006748795509
# Iteration 589 attack MSE: 0.03807578980922699
# Iteration 590 attack MSE: 0.04312756285071373
# Iteration 591 attack MSE: 0.03719944506883621
# Iteration 592 attack MSE: 0.03729540854692459
# Iteration 593 attack MSE: 0.040902119129896164
# Iteration 594 attack MSE: 0.03891006112098694
# Iteration 595 attack MSE: 0.037449732422828674
# Iteration 596 attack MSE: 0.03832213580608368
# Iteration 597 attack MSE: 0.038401201367378235
# Iteration 598 attack MSE: 0.03680189698934555
# Iteration 599 attack MSE: 0.04481012374162674
# Iteration 600 attack MSE: 0.037712499499320984
# Iteration 601 attack MSE: 0.04020453989505768
# Iteration 602 attack MSE: 0.03681154549121857
# Iteration 603 attack MSE: 0.03819223493337631
# Iteration 604 attack MSE: 0.036791764199733734
# Iteration 605 attack MSE: 0.039374109357595444
# Iteration 606 attack MSE: 0.03766302391886711
# Iteration 607 attack MSE: 0.039101555943489075
# Iteration 608 attack MSE: 0.03580479323863983
# Iteration 609 attack MSE: 0.03782613202929497
# Iteration 610 attack MSE: 0.03902529180049896
# Iteration 611 attack MSE: 0.03974361717700958
# Iteration 612 attack MSE: 0.042145323008298874
# Iteration 613 attack MSE: 0.03810720518231392
# Iteration 614 attack MSE: 0.03286345303058624
# Iteration 615 attack MSE: 0.03837231919169426
# Iteration 616 attack MSE: 0.03750118985772133
# Iteration 617 attack MSE: 0.03709153085947037
# Iteration 618 attack MSE: 0.03877048194408417
# Iteration 619 attack MSE: 0.040390729904174805
# Iteration 620 attack MSE: 0.03789232298731804
# Iteration 621 attack MSE: 0.03794664889574051
# Iteration 622 attack MSE: 0.038165826350450516
# Iteration 623 attack MSE: 0.0401839055120945
# Iteration 624 attack MSE: 0.03768296539783478
# Iteration 625 attack MSE: 0.03734545782208443
# Iteration 626 attack MSE: 0.0397113561630249
# Iteration 627 attack MSE: 0.037800323218107224
# Iteration 628 attack MSE: 0.04011048004031181
# Iteration 629 attack MSE: 0.04797392711043358
# Iteration 630 attack MSE: 0.0428663045167923
# Iteration 631 attack MSE: 0.039411984384059906
# Iteration 632 attack MSE: 0.039492666721343994
# Iteration 633 attack MSE: 0.04133293777704239
# Iteration 634 attack MSE: 0.04151454567909241
# Iteration 635 attack MSE: 0.04421040043234825
# Iteration 636 attack MSE: 0.04043607786297798
# Iteration 637 attack MSE: 0.04055732488632202
# Iteration 638 attack MSE: 0.04180850461125374
# Iteration 639 attack MSE: 0.041862018406391144
# Iteration 640 attack MSE: 0.04099791496992111
# Iteration 641 attack MSE: 0.04741013050079346
# Iteration 642 attack MSE: 0.041561052203178406
# Iteration 643 attack MSE: 0.040992751717567444
# Iteration 644 attack MSE: 0.040191516280174255
# Iteration 645 attack MSE: 0.03822513669729233
# Iteration 646 attack MSE: 0.03672880306839943
# Iteration 647 attack MSE: 0.041560523211956024
# Iteration 648 attack MSE: 0.0361894853413105
# Iteration 649 attack MSE: 0.040240250527858734
# Iteration 650 attack MSE: 0.04002945125102997
# Iteration 651 attack MSE: 0.038837213069200516
# Iteration 652 attack MSE: 0.0379432737827301
# Iteration 653 attack MSE: 0.035648413002491
# Iteration 654 attack MSE: 0.03839658945798874
# Iteration 655 attack MSE: 0.03646431490778923
# Iteration 656 attack MSE: 0.04071797430515289
# Iteration 657 attack MSE: 0.039870165288448334
# Iteration 658 attack MSE: 0.03572031855583191
# Iteration 659 attack MSE: 0.036939702928066254
# Iteration 660 attack MSE: 0.04109611362218857
# Iteration 661 attack MSE: 0.04177010431885719
# Iteration 662 attack MSE: 0.03854646161198616
# Iteration 663 attack MSE: 0.04101533815264702
# Iteration 664 attack MSE: 0.03845909982919693
# Iteration 665 attack MSE: 0.04338916391134262
# Iteration 666 attack MSE: 0.04066217690706253
# Iteration 667 attack MSE: 0.0400308258831501
# Iteration 668 attack MSE: 0.041907571256160736
# Iteration 669 attack MSE: 0.03834826499223709
# Iteration 670 attack MSE: 0.04131019487977028
# Iteration 671 attack MSE: 0.03881198912858963
# Iteration 672 attack MSE: 0.04573240876197815
# Iteration 673 attack MSE: 0.036997292190790176
# Iteration 674 attack MSE: 0.0376603901386261
# Iteration 675 attack MSE: 0.03938362002372742
# Iteration 676 attack MSE: 0.037184227257966995
# Iteration 677 attack MSE: 0.038751840591430664
# Iteration 678 attack MSE: 0.03396248072385788
# Iteration 679 attack MSE: 0.04549718648195267
# Iteration 680 attack MSE: 0.04368268698453903
# Iteration 681 attack MSE: 0.036342911422252655
# Iteration 682 attack MSE: 0.03699701279401779
# Iteration 683 attack MSE: 0.04064902663230896
# Iteration 684 attack MSE: 0.037664659321308136
# Iteration 685 attack MSE: 0.03758343309164047
# Iteration 686 attack MSE: 0.03463524952530861
# Iteration 687 attack MSE: 0.03854169696569443
# Iteration 688 attack MSE: 0.03550400957465172
# Iteration 689 attack MSE: 0.036180153489112854
# Iteration 690 attack MSE: 0.036344632506370544
# Iteration 691 attack MSE: 0.04130629450082779
# Iteration 692 attack MSE: 0.033970415592193604
# Iteration 693 attack MSE: 0.03771164268255234
# Iteration 694 attack MSE: 0.03620464727282524
# Iteration 695 attack MSE: 0.03571147844195366
# Iteration 696 attack MSE: 0.03698715567588806
# Iteration 697 attack MSE: 0.034359484910964966
# Iteration 698 attack MSE: 0.03885950893163681
# Iteration 699 attack MSE: 0.03413744270801544
# Iteration 700 attack MSE: 0.04214710742235184
# Iteration 701 attack MSE: 0.04089980572462082
# Iteration 702 attack MSE: 0.04065053164958954
# Iteration 703 attack MSE: 0.04073534160852432
# Iteration 704 attack MSE: 0.04139676317572594
# Iteration 705 attack MSE: 0.042045608162879944
# Iteration 706 attack MSE: 0.03536003455519676
# Iteration 707 attack MSE: 0.03978449106216431
# Iteration 708 attack MSE: 0.04461308568716049
# Iteration 709 attack MSE: 0.04151473939418793
# Iteration 710 attack MSE: 0.045087654143571854
# Iteration 711 attack MSE: 0.039398666471242905
# Iteration 712 attack MSE: 0.04074732959270477
# Iteration 713 attack MSE: 0.048002466559410095
# Iteration 714 attack MSE: 0.04128607362508774
# Iteration 715 attack MSE: 0.04586008936166763
# Iteration 716 attack MSE: 0.04013362526893616
# Iteration 717 attack MSE: 0.0444706454873085
# Iteration 718 attack MSE: 0.04656130075454712
# Iteration 719 attack MSE: 0.04298584535717964
# Iteration 720 attack MSE: 0.04558280110359192
# Iteration 721 attack MSE: 0.04378628730773926
# Iteration 722 attack MSE: 0.04502314329147339
# Iteration 723 attack MSE: 0.045041274279356
# Iteration 724 attack MSE: 0.04416801407933235
# Iteration 725 attack MSE: 0.041447825729846954
# Iteration 726 attack MSE: 0.039067499339580536
# Iteration 727 attack MSE: 0.03950794041156769
# Iteration 728 attack MSE: 0.043348900973796844
# Iteration 729 attack MSE: 0.040298670530319214
# Iteration 730 attack MSE: 0.03899839147925377
# Iteration 731 attack MSE: 0.04278431832790375
# Iteration 732 attack MSE: 0.04148237407207489
# Iteration 733 attack MSE: 0.0414581261575222
# Iteration 734 attack MSE: 0.041686274111270905
# Iteration 735 attack MSE: 0.04254554957151413
# Iteration 736 attack MSE: 0.038300223648548126
# Iteration 737 attack MSE: 0.03737699240446091
# Iteration 738 attack MSE: 0.0392744317650795
# Iteration 739 attack MSE: 0.03966134414076805
# Iteration 740 attack MSE: 0.0372055359184742
# Iteration 741 attack MSE: 0.039036765694618225
# Iteration 742 attack MSE: 0.04603289067745209
# Iteration 743 attack MSE: 0.03627226874232292
# Iteration 744 attack MSE: 0.039619602262973785
# Iteration 745 attack MSE: 0.04337793216109276
# Iteration 746 attack MSE: 0.0518026202917099
# Iteration 747 attack MSE: 0.042792342603206635
# Iteration 748 attack MSE: 0.035830724984407425
# Iteration 749 attack MSE: 0.04055744782090187
# Iteration 750 attack MSE: 0.04019533470273018
# Iteration 751 attack MSE: 0.042383089661598206
# Iteration 752 attack MSE: 0.041191715747117996
# Iteration 753 attack MSE: 0.03613197058439255
# Iteration 754 attack MSE: 0.035622186958789825
# Iteration 755 attack MSE: 0.043251149356365204
# Iteration 756 attack MSE: 0.038281284272670746
# Iteration 757 attack MSE: 0.040244653820991516
# Iteration 758 attack MSE: 0.03695371747016907
# Iteration 759 attack MSE: 0.03824027255177498
# Iteration 760 attack MSE: 0.039467282593250275
# Iteration 761 attack MSE: 0.03445672243833542
# Iteration 762 attack MSE: 0.031444452702999115
# Iteration 763 attack MSE: 0.043328385800123215
# Iteration 764 attack MSE: 0.04292759671807289
# Iteration 765 attack MSE: 0.03801398724317551
# Iteration 766 attack MSE: 0.03510388731956482
# Iteration 767 attack MSE: 0.03734530508518219
# Iteration 768 attack MSE: 0.03313850611448288
# Iteration 769 attack MSE: 0.038921892642974854
# Iteration 770 attack MSE: 0.035729922354221344
# Iteration 771 attack MSE: 0.04307819902896881
# Iteration 772 attack MSE: 0.037827737629413605
# Iteration 773 attack MSE: 0.0464433953166008
# Iteration 774 attack MSE: 0.03802432864904404
# Iteration 775 attack MSE: 0.04512828588485718
# Iteration 776 attack MSE: 0.0406496524810791
# Iteration 777 attack MSE: 0.03555072471499443
# Iteration 778 attack MSE: 0.03590158000588417
# Iteration 779 attack MSE: 0.03702583163976669
# Iteration 780 attack MSE: 0.04053085297346115
# Iteration 781 attack MSE: 0.036934200674295425
# Iteration 782 attack MSE: 0.03933760151267052
# Iteration 783 attack MSE: 0.038132861256599426
# Iteration 784 attack MSE: 0.034516483545303345
# Iteration 785 attack MSE: 0.037321362644433975
# Iteration 786 attack MSE: 0.037123903632164
# Iteration 787 attack MSE: 0.03602749854326248
# Iteration 788 attack MSE: 0.03828856348991394
# Iteration 789 attack MSE: 0.04028749093413353
# Iteration 790 attack MSE: 0.03764704614877701
# Iteration 791 attack MSE: 0.0385989248752594
# Iteration 792 attack MSE: 0.036869458854198456
# Iteration 793 attack MSE: 0.03808433562517166
# Iteration 794 attack MSE: 0.045531246811151505
# Iteration 795 attack MSE: 0.04260377958416939
# Iteration 796 attack MSE: 0.03624492138624191
# Iteration 797 attack MSE: 0.03812713921070099
# Iteration 798 attack MSE: 0.043276794254779816
# Iteration 799 attack MSE: 0.04411565884947777
# Iteration 800 attack MSE: 0.03991962969303131
# Iteration 801 attack MSE: 0.039424195885658264
# Iteration 802 attack MSE: 0.04423394799232483
# Iteration 803 attack MSE: 0.03986157849431038
# Iteration 804 attack MSE: 0.04618581011891365
# Iteration 805 attack MSE: 0.03995755314826965
# Iteration 806 attack MSE: 0.03768240660429001
# Iteration 807 attack MSE: 0.041325606405735016
# Iteration 808 attack MSE: 0.03661356121301651
# Iteration 809 attack MSE: 0.04107019677758217
# Iteration 810 attack MSE: 0.04070042073726654
# Iteration 811 attack MSE: 0.033936887979507446
# Iteration 812 attack MSE: 0.04147674888372421
# Iteration 813 attack MSE: 0.04271882027387619
# Iteration 814 attack MSE: 0.046523742377758026
# Iteration 815 attack MSE: 0.03997955098748207
# Iteration 816 attack MSE: 0.039016686379909515
# Iteration 817 attack MSE: 0.041952893137931824
# Iteration 818 attack MSE: 0.038335155695676804
# Iteration 819 attack MSE: 0.038969844579696655
# Iteration 820 attack MSE: 0.0422554612159729
# Iteration 821 attack MSE: 0.04444117471575737
# Iteration 822 attack MSE: 0.04204592853784561
# Iteration 823 attack MSE: 0.04067317023873329
# Iteration 824 attack MSE: 0.03880468010902405
# Iteration 825 attack MSE: 0.03555366396903992
# Iteration 826 attack MSE: 0.03522411733865738
# Iteration 827 attack MSE: 0.04005136713385582
# Iteration 828 attack MSE: 0.03572683036327362
# Iteration 829 attack MSE: 0.03908650577068329
# Iteration 830 attack MSE: 0.040361933410167694
# Iteration 831 attack MSE: 0.037908632308244705
# Iteration 832 attack MSE: 0.04024901241064072
# Iteration 833 attack MSE: 0.03756540268659592
# Iteration 834 attack MSE: 0.043414536863565445
# Iteration 835 attack MSE: 0.038706280291080475
# Iteration 836 attack MSE: 0.03551134467124939
# Iteration 837 attack MSE: 0.040737152099609375
# Iteration 838 attack MSE: 0.04003643989562988
# Iteration 839 attack MSE: 0.03789953142404556
# Iteration 840 attack MSE: 0.038379229605197906
# Iteration 841 attack MSE: 0.03817858546972275
# Iteration 842 attack MSE: 0.04038141295313835
# Iteration 843 attack MSE: 0.04130113124847412
# Iteration 844 attack MSE: 0.04388027638196945
# Iteration 845 attack MSE: 0.036522090435028076
# Iteration 846 attack MSE: 0.038255725055933
# Iteration 847 attack MSE: 0.03744989633560181
# Iteration 848 attack MSE: 0.038985803723335266
# Iteration 849 attack MSE: 0.04463693127036095
# Iteration 850 attack MSE: 0.03666575998067856
# Iteration 851 attack MSE: 0.041301704943180084
# Iteration 852 attack MSE: 0.038723886013031006
# Iteration 853 attack MSE: 0.03867968171834946
# Iteration 854 attack MSE: 0.03834129124879837
# Iteration 855 attack MSE: 0.039767004549503326
# Iteration 856 attack MSE: 0.03843725845217705
# Iteration 857 attack MSE: 0.03548889607191086
# Iteration 858 attack MSE: 0.037181127816438675
# Iteration 859 attack MSE: 0.038113757967948914
# Iteration 860 attack MSE: 0.0389416366815567
# Iteration 861 attack MSE: 0.03582988679409027
# Iteration 862 attack MSE: 0.04190612584352493
# Iteration 863 attack MSE: 0.04010738432407379
# Iteration 864 attack MSE: 0.04215626046061516
# Iteration 865 attack MSE: 0.03997792303562164
# Iteration 866 attack MSE: 0.04150478541851044
# Iteration 867 attack MSE: 0.038759879767894745
# Iteration 868 attack MSE: 0.04029408469796181
# Iteration 869 attack MSE: 0.04224291443824768
# Iteration 870 attack MSE: 0.03970006853342056
# Iteration 871 attack MSE: 0.036339640617370605
# Iteration 872 attack MSE: 0.033526454120874405
# Iteration 873 attack MSE: 0.03627079725265503
# Iteration 874 attack MSE: 0.04188285022974014
# Iteration 875 attack MSE: 0.039311595261096954
# Iteration 876 attack MSE: 0.04256423935294151
# Iteration 877 attack MSE: 0.038307011127471924
# Iteration 878 attack MSE: 0.041864484548568726
# Iteration 879 attack MSE: 0.03999491408467293
# Iteration 880 attack MSE: 0.0385272353887558
# Iteration 881 attack MSE: 0.033060330897569656
# Iteration 882 attack MSE: 0.04049680754542351
# Iteration 883 attack MSE: 0.035921309143304825
# Iteration 884 attack MSE: 0.036776065826416016
# Iteration 885 attack MSE: 0.03973126411437988
# Iteration 886 attack MSE: 0.037511344999074936
# Iteration 887 attack MSE: 0.03617541119456291
# Iteration 888 attack MSE: 0.03631610795855522
# Iteration 889 attack MSE: 0.03606719151139259
# Iteration 890 attack MSE: 0.03575383499264717
# Iteration 891 attack MSE: 0.037015125155448914
# Iteration 892 attack MSE: 0.042820803821086884
# Iteration 893 attack MSE: 0.03408847004175186
# Iteration 894 attack MSE: 0.039160870015621185
# Iteration 895 attack MSE: 0.03317751735448837
# Iteration 896 attack MSE: 0.034383270889520645
# Iteration 897 attack MSE: 0.032873570919036865
# Iteration 898 attack MSE: 0.03502490371465683
# Iteration 899 attack MSE: 0.03361786901950836
# Iteration 900 attack MSE: 0.03720656409859657
# Iteration 901 attack MSE: 0.03432869166135788
# Iteration 902 attack MSE: 0.037143126130104065
# Iteration 903 attack MSE: 0.03600340709090233
# Iteration 904 attack MSE: 0.034327782690525055
# Iteration 905 attack MSE: 0.033388618379831314
# Iteration 906 attack MSE: 0.041843537241220474
# Iteration 907 attack MSE: 0.03562723845243454
# Iteration 908 attack MSE: 0.036792825907468796
# Iteration 909 attack MSE: 0.03680893033742905
# Iteration 910 attack MSE: 0.03640411049127579
# Iteration 911 attack MSE: 0.03442651033401489
# Iteration 912 attack MSE: 0.03545374050736427
# Iteration 913 attack MSE: 0.034429874271154404
# Iteration 914 attack MSE: 0.04144437238574028
# Iteration 915 attack MSE: 0.03677315264940262
# Iteration 916 attack MSE: 0.037654731422662735
# Iteration 917 attack MSE: 0.03559630364179611
# Iteration 918 attack MSE: 0.039884865283966064
# Iteration 919 attack MSE: 0.03738927096128464
# Iteration 920 attack MSE: 0.035762034356594086
# Iteration 921 attack MSE: 0.042583856731653214
# Iteration 922 attack MSE: 0.032119955867528915
# Iteration 923 attack MSE: 0.039312392473220825
# Iteration 924 attack MSE: 0.03502563387155533
# Iteration 925 attack MSE: 0.030055968090891838
# Iteration 926 attack MSE: 0.036166075617074966
# Iteration 927 attack MSE: 0.03798097372055054
# Iteration 928 attack MSE: 0.03543604165315628
# Iteration 929 attack MSE: 0.03476736694574356
# Iteration 930 attack MSE: 0.038575608283281326
# Iteration 931 attack MSE: 0.03529059886932373
# Iteration 932 attack MSE: 0.03551821410655975
# Iteration 933 attack MSE: 0.03748026490211487
# Iteration 934 attack MSE: 0.03607642278075218
# Iteration 935 attack MSE: 0.03724716603755951
# Iteration 936 attack MSE: 0.031533174216747284
# Iteration 937 attack MSE: 0.0346960574388504
# Iteration 938 attack MSE: 0.03603269159793854
# Iteration 939 attack MSE: 0.03696688264608383
# Iteration 940 attack MSE: 0.036090053617954254
# Iteration 941 attack MSE: 0.03843093663454056
# Iteration 942 attack MSE: 0.03818884491920471
# Iteration 943 attack MSE: 0.03537581488490105
# Iteration 944 attack MSE: 0.035876765847206116
# Iteration 945 attack MSE: 0.04024326801300049
# Iteration 946 attack MSE: 0.03661879897117615
# Iteration 947 attack MSE: 0.03941064327955246
# Iteration 948 attack MSE: 0.03639848530292511
# Iteration 949 attack MSE: 0.03812800347805023
# Iteration 950 attack MSE: 0.03905315697193146
# Iteration 951 attack MSE: 0.035713307559490204
# Iteration 952 attack MSE: 0.03669367730617523
# Iteration 953 attack MSE: 0.036202557384967804
# Iteration 954 attack MSE: 0.03275040537118912
# Iteration 955 attack MSE: 0.031301047652959824
# Iteration 956 attack MSE: 0.03697426617145538
# Iteration 957 attack MSE: 0.036071039736270905
# Iteration 958 attack MSE: 0.03212166205048561
# Iteration 959 attack MSE: 0.035959914326667786
# Iteration 960 attack MSE: 0.03420419991016388
# Iteration 961 attack MSE: 0.03792143240571022
# Iteration 962 attack MSE: 0.034854594618082047
# Iteration 963 attack MSE: 0.03381095081567764
# Iteration 964 attack MSE: 0.036827921867370605
# Iteration 965 attack MSE: 0.03778906911611557
# Iteration 966 attack MSE: 0.033914126455783844
# Iteration 967 attack MSE: 0.033245183527469635
# Iteration 968 attack MSE: 0.03133462741971016
# Iteration 969 attack MSE: 0.0293402299284935
# Iteration 970 attack MSE: 0.032172657549381256
# Iteration 971 attack MSE: 0.034494005143642426
# Iteration 972 attack MSE: 0.031562358140945435
# Iteration 973 attack MSE: 0.0349457710981369
# Iteration 974 attack MSE: 0.03353079408407211
# Iteration 975 attack MSE: 0.032921627163887024
# Iteration 976 attack MSE: 0.03728741779923439
# Iteration 977 attack MSE: 0.030312446877360344
# Iteration 978 attack MSE: 0.03118652105331421
# Iteration 979 attack MSE: 0.03487952798604965
# Iteration 980 attack MSE: 0.03210661932826042
# Iteration 981 attack MSE: 0.035775430500507355
# Iteration 982 attack MSE: 0.03474605828523636
# Iteration 983 attack MSE: 0.03714296966791153
# Iteration 984 attack MSE: 0.036731965839862823
# Iteration 985 attack MSE: 0.03518667072057724
# Iteration 986 attack MSE: 0.03686051815748215
# Iteration 987 attack MSE: 0.036224059760570526
# Iteration 988 attack MSE: 0.03505382686853409
# Iteration 989 attack MSE: 0.034216247498989105
# Iteration 990 attack MSE: 0.03355128690600395
# Iteration 991 attack MSE: 0.03306863456964493
# Iteration 992 attack MSE: 0.03521985933184624
# Iteration 993 attack MSE: 0.034769900143146515
# Iteration 994 attack MSE: 0.035538382828235626
# Iteration 995 attack MSE: 0.03790219500660896
# Iteration 996 attack MSE: 0.03492668271064758
# Iteration 997 attack MSE: 0.03443572297692299
# Iteration 998 attack MSE: 0.03500530496239662
# Iteration 999 attack MSE: 0.03680875524878502
# Iteration 1000 attack MSE: 0.034259166568517685
# Iteration 1001 attack MSE: 0.03408307582139969
# Iteration 1002 attack MSE: 0.034607380628585815
# Iteration 1003 attack MSE: 0.030907174572348595
# Iteration 1004 attack MSE: 0.03170192986726761
# Iteration 1005 attack MSE: 0.03339576721191406
# Iteration 1006 attack MSE: 0.03497777879238129
# Iteration 1007 attack MSE: 0.034470945596694946
# Iteration 1008 attack MSE: 0.03344976156949997
# Iteration 1009 attack MSE: 0.03464529663324356
# Iteration 1010 attack MSE: 0.03571583703160286
# Iteration 1011 attack MSE: 0.037235014140605927
# Iteration 1012 attack MSE: 0.0370575450360775
# Iteration 1013 attack MSE: 0.0333644300699234
# Iteration 1014 attack MSE: 0.03469197452068329
# Iteration 1015 attack MSE: 0.03410516679286957
# Iteration 1016 attack MSE: 0.03798069804906845
# Iteration 1017 attack MSE: 0.03146689385175705
# Iteration 1018 attack MSE: 0.03456626087427139
# Iteration 1019 attack MSE: 0.03490174561738968
# Iteration 1020 attack MSE: 0.04141299054026604
# Iteration 1021 attack MSE: 0.03553308919072151
# Iteration 1022 attack MSE: 0.03725086897611618
# Iteration 1023 attack MSE: 0.03584732860326767
# Iteration 1024 attack MSE: 0.034565314650535583
# Iteration 1025 attack MSE: 0.03554891422390938
# Iteration 1026 attack MSE: 0.031281616538763046
# Iteration 1027 attack MSE: 0.03658226132392883
# Iteration 1028 attack MSE: 0.03468060865998268
# Iteration 1029 attack MSE: 0.0335540696978569
# Iteration 1030 attack MSE: 0.03310117870569229
# Iteration 1031 attack MSE: 0.03729766979813576
# Iteration 1032 attack MSE: 0.03845973312854767
# Iteration 1033 attack MSE: 0.041029658168554306
# Iteration 1034 attack MSE: 0.03966927155852318
# Iteration 1035 attack MSE: 0.038953956216573715
# Iteration 1036 attack MSE: 0.03888900205492973
# Iteration 1037 attack MSE: 0.03847833722829819
# Iteration 1038 attack MSE: 0.039775967597961426
# Iteration 1039 attack MSE: 0.03750963509082794
# Iteration 1040 attack MSE: 0.03710905462503433
# Iteration 1041 attack MSE: 0.0345151461660862
# Iteration 1042 attack MSE: 0.03750200569629669
# Iteration 1043 attack MSE: 0.034255251288414
# Iteration 1044 attack MSE: 0.03547424077987671
# ...
# Iteration 1664 attack MSE: 0.030670195817947388
# Iteration 1665 attack MSE: 0.030594557523727417
# Iteration 1666 attack MSE: 0.02877100184559822
# Iteration 1667 attack MSE: 0.03143426403403282
# Iteration 1668 attack MSE: 0.03298467397689819
# Iteration 1669 attack MSE: 0.02810400351881981
# Iteration 1670 attack MSE: 0.02880728244781494
# Iteration 1671 attack MSE: 0.032817527651786804
# Iteration 1672 attack MSE: 0.03170877322554588
# Iteration 1673 attack MSE: 0.03232041373848915
# Iteration 1674 attack MSE: 0.028864959254860878
# Iteration 1675 attack MSE: 0.028263917192816734
# Iteration 1676 attack MSE: 0.030604494735598564
# Iteration 1677 attack MSE: 0.03107636794447899
# Iteration 1678 attack MSE: 0.030466847121715546
# Iteration 1679 attack MSE: 0.031946584582328796
# Iteration 1680 attack MSE: 0.030453035607933998
# Iteration 1681 attack MSE: 0.02935640886425972
# Iteration 1682 attack MSE: 0.02928110584616661
# Iteration 1683 attack MSE: 0.03042547032237053
# Iteration 1684 attack MSE: 0.02916450798511505
# Iteration 1685 attack MSE: 0.031164029613137245
# Iteration 1686 attack MSE: 0.03158390894532204
# Iteration 1687 attack MSE: 0.03491748869419098
# Iteration 1688 attack MSE: 0.03181162849068642
# Iteration 1689 attack MSE: 0.033791683614254
# Iteration 1690 attack MSE: 0.030903123319149017
# Iteration 1691 attack MSE: 0.03377307951450348
# Iteration 1692 attack MSE: 0.030832888558506966
# Iteration 1693 attack MSE: 0.03275671973824501
# Iteration 1694 attack MSE: 0.030470984056591988
# Iteration 1695 attack MSE: 0.03281877562403679
# Iteration 1696 attack MSE: 0.03299260139465332
# Iteration 1697 attack MSE: 0.033000826835632324
# Iteration 1698 attack MSE: 0.031389836221933365
# Iteration 1699 attack MSE: 0.03211868181824684
# Iteration 1700 attack MSE: 0.03287003934383392
# Iteration 1701 attack MSE: 0.032560549676418304
# Iteration 1702 attack MSE: 0.0335751511156559
# Iteration 1703 attack MSE: 0.03158581256866455
# Iteration 1704 attack MSE: 0.036026839166879654
# Iteration 1705 attack MSE: 0.03643365204334259
# Iteration 1706 attack MSE: 0.03643026947975159
# Iteration 1707 attack MSE: 0.0349380224943161
# Iteration 1708 attack MSE: 0.03101622685790062
# Iteration 1709 attack MSE: 0.03635527938604355
# Iteration 1710 attack MSE: 0.03428754210472107
# Iteration 1711 attack MSE: 0.034646742045879364
# Iteration 1712 attack MSE: 0.03538750484585762
# Iteration 1713 attack MSE: 0.030342696234583855
# Iteration 1714 attack MSE: 0.035211797803640366
# Iteration 1715 attack MSE: 0.033746980130672455
# Iteration 1716 attack MSE: 0.031175978481769562
# Iteration 1717 attack MSE: 0.02971242368221283
# Iteration 1718 attack MSE: 0.034119557589292526
# Iteration 1719 attack MSE: 0.03188355267047882
# Iteration 1720 attack MSE: 0.032502271234989166
# Iteration 1721 attack MSE: 0.034705836325883865
# Iteration 1722 attack MSE: 0.03378274291753769
# Iteration 1723 attack MSE: 0.031657274812459946
# Iteration 1724 attack MSE: 0.03173501417040825
# Iteration 1725 attack MSE: 0.031033076345920563
# Iteration 1726 attack MSE: 0.031889259815216064
# Iteration 1727 attack MSE: 0.03402870148420334
# Iteration 1728 attack MSE: 0.034736763685941696
# Iteration 1729 attack MSE: 0.02777448296546936
# Iteration 1730 attack MSE: 0.030541658401489258
# Iteration 1731 attack MSE: 0.030391618609428406
# Iteration 1732 attack MSE: 0.03265787661075592
# Iteration 1733 attack MSE: 0.032386086881160736
# Iteration 1734 attack MSE: 0.03284451365470886
# Iteration 1735 attack MSE: 0.0281221941113472
# Iteration 1736 attack MSE: 0.03203420341014862
# Iteration 1737 attack MSE: 0.035264790058135986
# Iteration 1738 attack MSE: 0.035087987780570984
# Iteration 1739 attack MSE: 0.03074161522090435
# Iteration 1740 attack MSE: 0.03152424842119217
# Iteration 1741 attack MSE: 0.032357357442379
# Iteration 1742 attack MSE: 0.030557451769709587
# Iteration 1743 attack MSE: 0.029815178364515305
# Iteration 1744 attack MSE: 0.031517092138528824
# Iteration 1745 attack MSE: 0.03227272629737854
# Iteration 1746 attack MSE: 0.031114179641008377
# Iteration 1747 attack MSE: 0.03500691056251526
# Iteration 1748 attack MSE: 0.031866345554590225
# Iteration 1749 attack MSE: 0.03163747116923332
# Iteration 1750 attack MSE: 0.028778009116649628
# Iteration 1751 attack MSE: 0.03380256146192551
# Iteration 1752 attack MSE: 0.029404640197753906
# Iteration 1753 attack MSE: 0.030287206172943115
# Iteration 1754 attack MSE: 0.03103482909500599
# Iteration 1755 attack MSE: 0.033514320850372314
# Iteration 1756 attack MSE: 0.0317404568195343
# Iteration 1757 attack MSE: 0.030745528638362885
# Iteration 1758 attack MSE: 0.03198032081127167
# Iteration 1759 attack MSE: 0.034181803464889526
# Iteration 1760 attack MSE: 0.030170124024152756
# Iteration 1761 attack MSE: 0.03239820897579193
# Iteration 1762 attack MSE: 0.03551905229687691
# Iteration 1763 attack MSE: 0.03191104158759117
# Iteration 1764 attack MSE: 0.03405199572443962
# Iteration 1765 attack MSE: 0.03167594224214554
# Iteration 1766 attack MSE: 0.0369546115398407
# Iteration 1767 attack MSE: 0.029139414429664612
# Iteration 1768 attack MSE: 0.0314294807612896
# Iteration 1769 attack MSE: 0.0339365229010582
# Iteration 1770 attack MSE: 0.034064434468746185
# Iteration 1771 attack MSE: 0.03609620779752731
# Iteration 1772 attack MSE: 0.02920190989971161
# Iteration 1773 attack MSE: 0.03056848607957363
# Iteration 1774 attack MSE: 0.029624341055750847
# Iteration 1775 attack MSE: 0.03247257322072983
# Iteration 1776 attack MSE: 0.029382389038801193
# Iteration 1777 attack MSE: 0.03128969669342041
# Iteration 1778 attack MSE: 0.035994961857795715
# Iteration 1779 attack MSE: 0.0290692076086998
# Iteration 1780 attack MSE: 0.03329160809516907
# Iteration 1781 attack MSE: 0.031203273683786392
# Iteration 1782 attack MSE: 0.033884771168231964
# Iteration 1783 attack MSE: 0.032726649194955826
# Iteration 1784 attack MSE: 0.03345225006341934
# Iteration 1785 attack MSE: 0.03816192224621773
# Iteration 1786 attack MSE: 0.030955027788877487
# Iteration 1787 attack MSE: 0.03133785352110863
# Iteration 1788 attack MSE: 0.03372904658317566
# Iteration 1789 attack MSE: 0.03118756227195263
# Iteration 1790 attack MSE: 0.03210717812180519
# Iteration 1791 attack MSE: 0.028082188218832016
# Iteration 1792 attack MSE: 0.03473098948597908
# Iteration 1793 attack MSE: 0.03527729958295822
# Iteration 1794 attack MSE: 0.031661856919527054
# Iteration 1795 attack MSE: 0.03333691135048866
# Iteration 1796 attack MSE: 0.03151645138859749
# Iteration 1797 attack MSE: 0.03493139147758484
# Iteration 1798 attack MSE: 0.035916589200496674
# Iteration 1799 attack MSE: 0.03189569711685181
# Iteration 1800 attack MSE: 0.029744669795036316
# Iteration 1801 attack MSE: 0.03196034952998161
# Iteration 1802 attack MSE: 0.029907021671533585
# Iteration 1803 attack MSE: 0.029149305075407028
# Iteration 1804 attack MSE: 0.032536767423152924
# Iteration 1805 attack MSE: 0.035072583705186844
# Iteration 1806 attack MSE: 0.035982489585876465
# Iteration 1807 attack MSE: 0.032046783715486526
# Iteration 1808 attack MSE: 0.03092179447412491
# Iteration 1809 attack MSE: 0.03026692569255829
# Iteration 1810 attack MSE: 0.03223426640033722
# Iteration 1811 attack MSE: 0.03467695787549019
# Iteration 1812 attack MSE: 0.03283383697271347
# Iteration 1813 attack MSE: 0.03223276138305664
# Iteration 1814 attack MSE: 0.02899739146232605
# Iteration 1815 attack MSE: 0.028788095340132713
# Iteration 1816 attack MSE: 0.030744120478630066
# Iteration 1817 attack MSE: 0.029410388320684433
# Iteration 1818 attack MSE: 0.03054210916161537
# Iteration 1819 attack MSE: 0.034290947020053864
# Iteration 1820 attack MSE: 0.03076271340250969
# Iteration 1821 attack MSE: 0.030628783628344536
# Iteration 1822 attack MSE: 0.030292373150587082
# Iteration 1823 attack MSE: 0.0306190624833107
# Iteration 1824 attack MSE: 0.028337929397821426
# Iteration 1825 attack MSE: 0.030178509652614594
# Iteration 1826 attack MSE: 0.0327000766992569
# Iteration 1827 attack MSE: 0.031156495213508606
# Iteration 1828 attack MSE: 0.0286332406103611
# Iteration 1829 attack MSE: 0.028490770608186722
# Iteration 1830 attack MSE: 0.026794053614139557
# Iteration 1831 attack MSE: 0.03157995268702507
# Iteration 1832 attack MSE: 0.03491801396012306
# Iteration 1833 attack MSE: 0.03238014131784439
# Iteration 1834 attack MSE: 0.030101507902145386
# Iteration 1835 attack MSE: 0.03360229730606079
# Iteration 1836 attack MSE: 0.033624157309532166
# Iteration 1837 attack MSE: 0.029094595462083817
# Iteration 1838 attack MSE: 0.031213775277137756
# Iteration 1839 attack MSE: 0.02940068393945694
# Iteration 1840 attack MSE: 0.03140131011605263
# Iteration 1841 attack MSE: 0.029229898005723953
# Iteration 1842 attack MSE: 0.0313655249774456
# Iteration 1843 attack MSE: 0.030610308051109314
# Iteration 1844 attack MSE: 0.028948791325092316
# Iteration 1845 attack MSE: 0.03126361593604088
# Iteration 1846 attack MSE: 0.028878673911094666
# Iteration 1847 attack MSE: 0.02943875640630722
# Iteration 1848 attack MSE: 0.03128432482481003
# Iteration 1849 attack MSE: 0.030531546100974083
# Iteration 1850 attack MSE: 0.030048517510294914
# Iteration 1851 attack MSE: 0.030505623668432236
# Iteration 1852 attack MSE: 0.030865691602230072
# Iteration 1853 attack MSE: 0.03206463158130646
# Iteration 1854 attack MSE: 0.02875692956149578
# Iteration 1855 attack MSE: 0.029940759763121605
# Iteration 1856 attack MSE: 0.02943519689142704
# Iteration 1857 attack MSE: 0.02771691605448723
# Iteration 1858 attack MSE: 0.036781083792448044
# Iteration 1859 attack MSE: 0.03049433045089245
# Iteration 1860 attack MSE: 0.030180949717760086
# Iteration 1861 attack MSE: 0.03086339682340622
# Iteration 1862 attack MSE: 0.03194395452737808
# Iteration 1863 attack MSE: 0.030237503349781036
# Iteration 1864 attack MSE: 0.029485147446393967
# Iteration 1865 attack MSE: 0.03212827444076538
# Iteration 1866 attack MSE: 0.031031642109155655
# Iteration 1867 attack MSE: 0.034179043024778366
# Iteration 1868 attack MSE: 0.033911000937223434
# Iteration 1869 attack MSE: 0.030631043016910553
# Iteration 1870 attack MSE: 0.03050636500120163
# Iteration 1871 attack MSE: 0.03296677768230438
# Iteration 1872 attack MSE: 0.031557224690914154
# Iteration 1873 attack MSE: 0.03112175129354
# Iteration 1874 attack MSE: 0.027983788400888443
# Iteration 1875 attack MSE: 0.03236894682049751
# Iteration 1876 attack MSE: 0.03197069466114044
# Iteration 1877 attack MSE: 0.03186142072081566
# Iteration 1878 attack MSE: 0.03166096657514572
# Iteration 1879 attack MSE: 0.030820298939943314
# Iteration 1880 attack MSE: 0.03329409658908844
# Iteration 1881 attack MSE: 0.03207100182771683
# Iteration 1882 attack MSE: 0.033527836203575134
# Iteration 1883 attack MSE: 0.03300370275974274
# Iteration 1884 attack MSE: 0.032264143228530884
# Iteration 1885 attack MSE: 0.03475736454129219
# Iteration 1886 attack MSE: 0.030596010386943817
# Iteration 1887 attack MSE: 0.03142232447862625
# Iteration 1888 attack MSE: 0.033403731882572174
# Iteration 1889 attack MSE: 0.03097127005457878
# Iteration 1890 attack MSE: 0.035550862550735474
# Iteration 1891 attack MSE: 0.034200333058834076
# Iteration 1892 attack MSE: 0.03155745565891266
# Iteration 1893 attack MSE: 0.031690746545791626
# Iteration 1894 attack MSE: 0.03149828314781189
# Iteration 1895 attack MSE: 0.031106214970350266
# Iteration 1896 attack MSE: 0.03429973125457764
# Iteration 1897 attack MSE: 0.029052734375
# Iteration 1898 attack MSE: 0.031060436740517616
# Iteration 1899 attack MSE: 0.034478556364774704
# Iteration 1900 attack MSE: 0.032866470515728
# Iteration 1901 attack MSE: 0.03274393826723099
# Iteration 1902 attack MSE: 0.031155476346611977
# Iteration 1903 attack MSE: 0.03280527889728546
# Iteration 1904 attack MSE: 0.03209935128688812
# Iteration 1905 attack MSE: 0.030936112627387047
# Iteration 1906 attack MSE: 0.02917543426156044
# Iteration 1907 attack MSE: 0.03175473213195801
# Iteration 1908 attack MSE: 0.03220460191369057
# Iteration 1909 attack MSE: 0.03256610035896301
# Iteration 1910 attack MSE: 0.03562275692820549
# Iteration 1911 attack MSE: 0.031470030546188354
# Iteration 1912 attack MSE: 0.031087005510926247
# Iteration 1913 attack MSE: 0.035510167479515076
# Iteration 1914 attack MSE: 0.033491458743810654
# Iteration 1915 attack MSE: 0.03197794780135155
# Iteration 1916 attack MSE: 0.03125584125518799
# Iteration 1917 attack MSE: 0.03691462427377701
# Iteration 1918 attack MSE: 0.03390859439969063
# Iteration 1919 attack MSE: 0.030753472819924355
# Iteration 1920 attack MSE: 0.028769446536898613
# Iteration 1921 attack MSE: 0.03336212411522865
# Iteration 1922 attack MSE: 0.030128061771392822
# Iteration 1923 attack MSE: 0.031911179423332214
# Iteration 1924 attack MSE: 0.029587535187602043
# Iteration 1925 attack MSE: 0.03412206470966339
# Iteration 1926 attack MSE: 0.03516768664121628
# Iteration 1927 attack MSE: 0.031045904383063316
# Iteration 1928 attack MSE: 0.032756507396698
# Iteration 1929 attack MSE: 0.03170274943113327
# Iteration 1930 attack MSE: 0.03080596588551998
# Iteration 1931 attack MSE: 0.030979998409748077
# Iteration 1932 attack MSE: 0.03141343593597412
# Iteration 1933 attack MSE: 0.029637377709150314
# Iteration 1934 attack MSE: 0.029779886826872826
# Iteration 1935 attack MSE: 0.033220671117305756
# Iteration 1936 attack MSE: 0.03053043782711029
# Iteration 1937 attack MSE: 0.029768463224172592
# Iteration 1938 attack MSE: 0.03013737127184868
# Iteration 1939 attack MSE: 0.026374435052275658
# Iteration 1940 attack MSE: 0.03173027187585831
# Iteration 1941 attack MSE: 0.028053630143404007
# Iteration 1942 attack MSE: 0.03003300353884697
# Iteration 1943 attack MSE: 0.029546048492193222
# Iteration 1944 attack MSE: 0.02944362163543701
# Iteration 1945 attack MSE: 0.027642101049423218
# Iteration 1946 attack MSE: 0.029941827058792114
# Iteration 1947 attack MSE: 0.028315125033259392
# Iteration 1948 attack MSE: 0.03260023891925812
# Iteration 1949 attack MSE: 0.031084390357136726
# Iteration 1950 attack MSE: 0.029126036912202835
# Iteration 1951 attack MSE: 0.03041151911020279
# Iteration 1952 attack MSE: 0.029970936477184296
# Iteration 1953 attack MSE: 0.031489547342061996
# Iteration 1954 attack MSE: 0.028965801000595093
# Iteration 1955 attack MSE: 0.030591409653425217
# Iteration 1956 attack MSE: 0.02717597410082817
# Iteration 1957 attack MSE: 0.027213357388973236
# Iteration 1958 attack MSE: 0.02873973920941353
# Iteration 1959 attack MSE: 0.028924554586410522
# Iteration 1960 attack MSE: 0.030765431001782417
# Iteration 1961 attack MSE: 0.031207719817757607
# Iteration 1962 attack MSE: 0.027964085340499878
# Iteration 1963 attack MSE: 0.027425523847341537
# Iteration 1964 attack MSE: 0.0318811759352684
# Iteration 1965 attack MSE: 0.029464952647686005
# Iteration 1966 attack MSE: 0.03253457695245743
# Iteration 1967 attack MSE: 0.030339740216732025
# Iteration 1968 attack MSE: 0.030226359143853188
# Iteration 1969 attack MSE: 0.028069861233234406
# Iteration 1970 attack MSE: 0.031718723475933075
# Iteration 1971 attack MSE: 0.03408360108733177
# Iteration 1972 attack MSE: 0.030987411737442017
# Iteration 1973 attack MSE: 0.030738336965441704
# Iteration 1974 attack MSE: 0.02762986160814762
# Iteration 1975 attack MSE: 0.02715815044939518
# Iteration 1976 attack MSE: 0.02857067435979843
# Iteration 1977 attack MSE: 0.027565717697143555
# Iteration 1978 attack MSE: 0.03041841834783554
# Iteration 1979 attack MSE: 0.03048938512802124
# Iteration 1980 attack MSE: 0.029758885502815247
# Iteration 1981 attack MSE: 0.028505969792604446
# Iteration 1982 attack MSE: 0.03358829766511917
# Iteration 1983 attack MSE: 0.02868606150150299
# Iteration 1984 attack MSE: 0.026319820433855057
# Iteration 1985 attack MSE: 0.03134477511048317
# Iteration 1986 attack MSE: 0.031735219061374664
# Iteration 1987 attack MSE: 0.029015863314270973
# Iteration 1988 attack MSE: 0.03246799856424332
# Iteration 1989 attack MSE: 0.03100183978676796
# Iteration 1990 attack MSE: 0.028567379340529442
# Iteration 1991 attack MSE: 0.029698284342885017
# Iteration 1992 attack MSE: 0.029330356046557426
# Iteration 1993 attack MSE: 0.028833400458097458
# Iteration 1994 attack MSE: 0.0313819944858551
# Iteration 1995 attack MSE: 0.03158991411328316
# Iteration 1996 attack MSE: 0.029880870133638382
# Iteration 1997 attack MSE: 0.031419314444065094
# Iteration 1998 attack MSE: 0.03029784746468067
# Iteration 1999 attack MSE: 0.02911178395152092
# Iteration 2000 attack MSE: 0.028768839314579964

# %%
attacked_img = rec_x_private[15:35,:,:,:]
original_img = x_private[15:35,:,:,:]

def plot(X):
    n = len(X)
    X = (X+1)/2
    fig, ax = plt.subplots(1, n, figsize=(n*3,3))
    plt.axis('off')
    plt.subplots_adjust(wspace=0, hspace=-.05)
    for i in range(n):
        ax[i].imshow((X[i]), cmap='inferno');  
        ax[i].set(xticks=[], yticks=[])
        ax[i].set_aspect('equal')
        
    return fig

fig = plot(original_img)
fig = plot(attacked_img)

# %%
log_freq = 50
sampled_log_10 = [log[i*log_freq] for i in range(int(len(log)/log_freq))]
log_100 = np.loadtxt("./log/cifar100.csv")
sampled_log_100 = [log_100[i*log_freq] for i in range(int(len(log_100)/log_freq))]
log_cross = np.loadtxt("./log/cifar_cross.csv")
sampled_log_cross = [log_cross[i*log_freq] for i in range(int(len(log_cross)/log_freq))]
plt.title("Decoding Simulator Attack Reconstruction MSE")
plt.ylabel('loss')
plt.xlabel('iteration')
ran = [i * log_freq for i in range(int(len(log)/log_freq))]
plt.plot(ran, sampled_log_10, 'ro-', ran, sampled_log_100, 'b^-', ran, sampled_log_cross, 'gs-', markevery=5)
plt.legend(['CIFAR10 against CIFAR10', 'CIFAR100 against CIFAR100', 'CIFAR100 against CIFAR10'], loc='upper right')
# plt.show()
plt.savefig("fig/cifar-compare.pdf")

# %%
np.savetxt('./log/cifar10.csv', log, delimiter=',')

# %% [markdown]
# Seems all right!
