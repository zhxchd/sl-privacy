# %% [markdown]
# # Server-side Feature Inference Attacks against Split Learning: MNIST Digits
#
# Experiments when decorrelation is applied to minimize information leakage.

# %% [markdown]
# ## Import packages and dataset

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

import sl_with_attack
from sl_with_attack import *
from datasets import *

xpriv, xpub = load_mnist()

# %% [markdown]
# ## Setting up hyperparameters and util functions

# %%
batch_size = 64
id_setup = 4
hparams = {
    'WGAN' : True,
    'gradient_penalty' : 500.,
    'style_loss' : None,
    'lr_f' :  0.00001,
    'lr_tilde' : 0.00001,
    'lr_D' : 0.0001,
    'lr_classify': 0.000001,
    'alpha': (100.0, 1.0),
}

iterations = 10000
log_frequency = 200

def plot_log(ax, x, y, label=None, color='blue'):
    ax.plot(x, y, color=color)
    ax.grid()
    if label is not None:
        ax.set(title=label)

# %% [markdown]
# ## Model architectures

# %%
def ResBlock(inputs, dim, ks=3, bn=False, activation='relu', reduce=1):
    x = inputs
    
    stride = reduce
    
    if bn:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(dim, ks, stride, padding='same')(x)
    
    if bn:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation(activation)(x)
    x = tf.keras.layers.Conv2D(dim, ks, padding='same')(x)
    
    if reduce > 1:
        inputs = tf.keras.layers.Conv2D(dim, ks, stride, padding='same')(inputs)
    
    return inputs + x

def f(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    x = tf.keras.layers.Conv2D(64, 3, 1, padding='same')(xin)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(2)(x)
    x = ResBlock(x, 64)
    x = ResBlock(x, 128, reduce=2)
    x = ResBlock(x, 128)
    x = ResBlock(x, 256, reduce=2)
    return tf.keras.Model(xin, x)

def g(input_shape, class_num):
    xin = tf.keras.layers.Input(input_shape)
    x = xin
    x = ResBlock(xin, 256)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if class_num == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = class_num

    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(units, activation=activation)(x)
    return tf.keras.Model(xin, x)

def encoder(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    act = None
    x = tf.keras.layers.Conv2D(64, 3, 2, padding='same', activation=act)(xin)
    x = tf.keras.layers.Conv2D(128, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2D(256, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2D(256, 3, 1, padding='same')(x)
    return tf.keras.Model(xin, x)

def decoder(input_shape, channels=3):
    xin = tf.keras.layers.Input(input_shape)
    act = None
    x = tf.keras.layers.Conv2DTranspose(256, 3, 2, padding='same', activation=act)(xin)
    x = tf.keras.layers.Conv2DTranspose(128, 3, 2, padding='same', activation=act)(x)
    x = tf.keras.layers.Conv2DTranspose(channels, 3, 2, padding='same', activation="tanh")(x)
    return tf.keras.Model(xin, x)

def discriminator(input_shape):
    xin = tf.keras.layers.Input(input_shape)
    x = tf.keras.layers.Conv2D(256, 3, 1, padding='same')(xin)
    bn = False
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = ResBlock(x, 256, bn=bn)
    x = tf.keras.layers.Conv2D(256, 3, 2, padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(xin, x)

# %%
models = (f, g, encoder, decoder, discriminator)

# %% [markdown]
# ## Active attack: reconstruction performance reference

# %%
active = sl_with_attack(models, xpriv, xpub, id_setup-1, batch_size, hparams, 10, server_attack="active")
log_active = active(iterations, verbose=True, progress_bar=False, log_frequency=log_frequency)
# Out:
# Minimize distance correlation with alpha1=100.0 and alpha2=1.0
# RUNNING...
# [log--01%-0000199] reconstruction validation: 0.6054
# Original task: train loss: 3.3784 train accuracy: 0.1327
# [log--03%-0000399] reconstruction validation: 0.2061
# Original task: train loss: 3.2364 train accuracy: 0.1522
# [log--05%-0000599] reconstruction validation: 0.1833
# Original task: train loss: 2.8648 train accuracy: 0.2058
# [log--07%-0000799] reconstruction validation: 0.1721
# Original task: train loss: 2.5003 train accuracy: 0.2773
# [log--09%-0000999] reconstruction validation: 0.1557
# Original task: train loss: 2.2024 train accuracy: 0.3426
# [log--11%-0001199] reconstruction validation: 0.1239
# Original task: train loss: 2.0493 train accuracy: 0.3680
# [log--13%-0001399] reconstruction validation: 0.1035
# Original task: train loss: 1.9218 train accuracy: 0.4034
# [log--15%-0001599] reconstruction validation: 0.0805
# Original task: train loss: 1.7488 train accuracy: 0.4484
# [log--17%-0001799] reconstruction validation: 0.0650
# Original task: train loss: 1.6256 train accuracy: 0.4814
# [log--19%-0001999] reconstruction validation: 0.0554
# Original task: train loss: 1.5367 train accuracy: 0.5063
# [log--21%-0002199] reconstruction validation: 0.0490
# Original task: train loss: 1.4695 train accuracy: 0.5301
# [log--23%-0002399] reconstruction validation: 0.0470
# Original task: train loss: 1.3874 train accuracy: 0.5520
# [log--25%-0002599] reconstruction validation: 0.0436
# Original task: train loss: 1.2885 train accuracy: 0.5847
# [log--27%-0002799] reconstruction validation: 0.0410
# Original task: train loss: 1.1515 train accuracy: 0.6274
# [log--29%-0002999] reconstruction validation: 0.0377
# Original task: train loss: 1.1324 train accuracy: 0.6377
# [log--31%-0003199] reconstruction validation: 0.0359
# Original task: train loss: 1.0683 train accuracy: 0.6600
# [log--33%-0003399] reconstruction validation: 0.0359
# Original task: train loss: 1.0260 train accuracy: 0.6755
# [log--35%-0003599] reconstruction validation: 0.0338
# Original task: train loss: 0.9830 train accuracy: 0.6820
# [log--37%-0003799] reconstruction validation: 0.0322
# Original task: train loss: 0.9112 train accuracy: 0.7108
# [log--39%-0003999] reconstruction validation: 0.0333
# Original task: train loss: 0.9323 train accuracy: 0.7043
# [log--41%-0004199] reconstruction validation: 0.0303
# Original task: train loss: 0.8868 train accuracy: 0.7204
# [log--43%-0004399] reconstruction validation: 0.0309
# Original task: train loss: 0.8890 train accuracy: 0.7166
# [log--45%-0004599] reconstruction validation: 0.0299
# Original task: train loss: 0.8357 train accuracy: 0.7376
# [log--47%-0004799] reconstruction validation: 0.0315
# Original task: train loss: 0.8094 train accuracy: 0.7416
# [log--49%-0004999] reconstruction validation: 0.0306
# Original task: train loss: 0.8151 train accuracy: 0.7472
# [log--51%-0005199] reconstruction validation: 0.0290
# Original task: train loss: 0.7973 train accuracy: 0.7463
# [log--53%-0005399] reconstruction validation: 0.0280
# Original task: train loss: 0.7938 train accuracy: 0.7508
# [log--55%-0005599] reconstruction validation: 0.0278
# Original task: train loss: 0.7015 train accuracy: 0.7770
# [log--57%-0005799] reconstruction validation: 0.0283
# Original task: train loss: 0.7339 train accuracy: 0.7713
# [log--59%-0005999] reconstruction validation: 0.0294
# Original task: train loss: 0.7404 train accuracy: 0.7714
# [log--61%-0006199] reconstruction validation: 0.0268
# Original task: train loss: 0.7060 train accuracy: 0.7803
# [log--63%-0006399] reconstruction validation: 0.0267
# Original task: train loss: 0.7005 train accuracy: 0.7828
# [log--65%-0006599] reconstruction validation: 0.0294
# Original task: train loss: 0.6685 train accuracy: 0.7952
# [log--67%-0006799] reconstruction validation: 0.0279
# Original task: train loss: 0.6645 train accuracy: 0.7934
# [log--69%-0006999] reconstruction validation: 0.0285
# Original task: train loss: 0.6840 train accuracy: 0.7934
# [log--71%-0007199] reconstruction validation: 0.0245
# Original task: train loss: 0.6713 train accuracy: 0.7884
# [log--73%-0007399] reconstruction validation: 0.0258
# Original task: train loss: 0.6396 train accuracy: 0.8011
# [log--75%-0007599] reconstruction validation: 0.0258
# Original task: train loss: 0.6094 train accuracy: 0.8125
# [log--77%-0007799] reconstruction validation: 0.0237
# Original task: train loss: 0.6472 train accuracy: 0.8042
# [log--79%-0007999] reconstruction validation: 0.0303
# Original task: train loss: 0.6413 train accuracy: 0.7989
# [log--81%-0008199] reconstruction validation: 0.0275
# Original task: train loss: 0.6245 train accuracy: 0.8071
# [log--83%-0008399] reconstruction validation: 0.0242
# Original task: train loss: 0.5738 train accuracy: 0.8212
# [log--85%-0008599] reconstruction validation: 0.0276
# Original task: train loss: 0.6080 train accuracy: 0.8155
# [log--87%-0008799] reconstruction validation: 0.0280
# Original task: train loss: 0.5906 train accuracy: 0.8166
# [log--89%-0008999] reconstruction validation: 0.0231
# Original task: train loss: 0.5828 train accuracy: 0.8197
# [log--91%-0009199] reconstruction validation: 0.0264
# Original task: train loss: 0.6056 train accuracy: 0.8123
# [log--93%-0009399] reconstruction validation: 0.0261
# Original task: train loss: 0.5561 train accuracy: 0.8256
# [log--95%-0009599] reconstruction validation: 0.0287
# Original task: train loss: 0.5793 train accuracy: 0.8177
# [log--97%-0009799] reconstruction validation: 0.0220
# Original task: train loss: 0.5683 train accuracy: 0.8255
# [log--99%-0009999] reconstruction validation: 0.0281
# Original task: train loss: 0.5632 train accuracy: 0.8224

# %%
n = 6
fix, ax = plt.subplots(1, n, figsize=(n*5, 4))
x = np.arange(0, len(log_active)) * log_frequency 

plot_log(ax[0], x, log_active[:, 0],  label='f loss')
plot_log(ax[1], x, log_active[:, 1],  label='Encoder/decoder loss')
plot_log(ax[2], x, log_active[:, 2],  label='D loss')
plot_log(ax[3], x, log_active[:, 3],  label='Reconstruction error')
plot_log(ax[4], x, log_active[:, 4], label='Training loss')
# plot_log(ax[4], x, log_no_attack[:,0], color='red')
plot_log(ax[5], x, log_active[:, 5],  label='Training accuracy')
# plot_log(ax[5], x, log_no_attack[:,1], color='red')

# %%
n = 20
X = getImagesDS(xpriv, n)
X_recovered, control = active.attack(X)

def plot(X):
    n = len(X)
    X = (X+1)/2
    fig, ax = plt.subplots(1, n, figsize=(n*3,3))
    plt.axis('off')
    plt.subplots_adjust(wspace=0, hspace=-.05)
    for i in range(n):
        ax[i].imshow((X[i]), cmap='inferno');  
        ax[i].set(xticks=[], yticks=[])
        ax[i].set_aspect('equal')
    return fig


fig = plot(X)
fig = plot(X_recovered)

# %% [markdown]
# ## Passive Attack

# %%
passive = sl_with_attack(models, xpriv, xpub, id_setup-1, batch_size, hparams, 10, server_attack="passive")
log_passive = passive(iterations, verbose=True, progress_bar=False, log_frequency=log_frequency)
# Out:
# Minimize distance correlation with alpha1=100.0 and alpha2=1.0
# RUNNING...
# [log--01%-0000199] reconstruction validation: 0.6386
# Original task: train loss: 2.7728 train accuracy: 0.2350
# [log--03%-0000399] reconstruction validation: 0.2591
# Original task: train loss: 1.5531 train accuracy: 0.5129
# [log--05%-0000599] reconstruction validation: 0.1486
# Original task: train loss: 1.1250 train accuracy: 0.6413
# [log--07%-0000799] reconstruction validation: 0.1197
# Original task: train loss: 0.8609 train accuracy: 0.7270
# [log--09%-0000999] reconstruction validation: 0.1065
# Original task: train loss: 0.7071 train accuracy: 0.7788
# [log--11%-0001199] reconstruction validation: 0.1003
# Original task: train loss: 0.6687 train accuracy: 0.7931
# [log--13%-0001399] reconstruction validation: 0.0982
# Original task: train loss: 0.6081 train accuracy: 0.8084
# [log--15%-0001599] reconstruction validation: 0.0858
# Original task: train loss: 0.5537 train accuracy: 0.8270
# [log--17%-0001799] reconstruction validation: 0.0753
# Original task: train loss: 0.4883 train accuracy: 0.8480
# [log--19%-0001999] reconstruction validation: 0.0681
# Original task: train loss: 0.4542 train accuracy: 0.8586
# [log--21%-0002199] reconstruction validation: 0.0623
# Original task: train loss: 0.4359 train accuracy: 0.8680
# [log--23%-0002399] reconstruction validation: 0.0599
# Original task: train loss: 0.4251 train accuracy: 0.8675
# [log--25%-0002599] reconstruction validation: 0.0570
# Original task: train loss: 0.4030 train accuracy: 0.8733
# [log--27%-0002799] reconstruction validation: 0.0556
# Original task: train loss: 0.3598 train accuracy: 0.8879
# [log--29%-0002999] reconstruction validation: 0.0537
# Original task: train loss: 0.3637 train accuracy: 0.8875
# [log--31%-0003199] reconstruction validation: 0.0523
# Original task: train loss: 0.3476 train accuracy: 0.8909
# [log--33%-0003399] reconstruction validation: 0.0515
# Original task: train loss: 0.3488 train accuracy: 0.8945
# [log--35%-0003599] reconstruction validation: 0.0503
# Original task: train loss: 0.3293 train accuracy: 0.9013
# [log--37%-0003799] reconstruction validation: 0.0493
# Original task: train loss: 0.3078 train accuracy: 0.9080
# [log--39%-0003999] reconstruction validation: 0.0470
# Original task: train loss: 0.3070 train accuracy: 0.9055
# [log--41%-0004199] reconstruction validation: 0.0459
# Original task: train loss: 0.2898 train accuracy: 0.9111
# [log--43%-0004399] reconstruction validation: 0.0453
# Original task: train loss: 0.3000 train accuracy: 0.9076
# [log--45%-0004599] reconstruction validation: 0.0446
# Original task: train loss: 0.2646 train accuracy: 0.9182
# [log--47%-0004799] reconstruction validation: 0.0441
# Original task: train loss: 0.2593 train accuracy: 0.9202
# [log--49%-0004999] reconstruction validation: 0.0429
# Original task: train loss: 0.2588 train accuracy: 0.9190
# [log--51%-0005199] reconstruction validation: 0.0429
# Original task: train loss: 0.2596 train accuracy: 0.9212
# [log--53%-0005399] reconstruction validation: 0.0424
# Original task: train loss: 0.2528 train accuracy: 0.9215
# [log--55%-0005599] reconstruction validation: 0.0420
# Original task: train loss: 0.2361 train accuracy: 0.9286
# [log--57%-0005799] reconstruction validation: 0.0419
# Original task: train loss: 0.2149 train accuracy: 0.9346
# [log--59%-0005999] reconstruction validation: 0.0419
# Original task: train loss: 0.2268 train accuracy: 0.9299
# [log--61%-0006199] reconstruction validation: 0.0420
# Original task: train loss: 0.2248 train accuracy: 0.9312
# [log--63%-0006399] reconstruction validation: 0.0418
# Original task: train loss: 0.2246 train accuracy: 0.9305
# [log--65%-0006599] reconstruction validation: 0.0412
# Original task: train loss: 0.1957 train accuracy: 0.9402
# [log--67%-0006799] reconstruction validation: 0.0413
# Original task: train loss: 0.2025 train accuracy: 0.9372
# [log--69%-0006999] reconstruction validation: 0.0416
# Original task: train loss: 0.2017 train accuracy: 0.9390
# [log--71%-0007199] reconstruction validation: 0.0416
# Original task: train loss: 0.2095 train accuracy: 0.9352
# [log--73%-0007399] reconstruction validation: 0.0422
# Original task: train loss: 0.1906 train accuracy: 0.9414
# [log--75%-0007599] reconstruction validation: 0.0420
# Original task: train loss: 0.1829 train accuracy: 0.9454
# [log--77%-0007799] reconstruction validation: 0.0417
# Original task: train loss: 0.1882 train accuracy: 0.9433
# [log--79%-0007999] reconstruction validation: 0.0419
# Original task: train loss: 0.1852 train accuracy: 0.9427
# [log--81%-0008199] reconstruction validation: 0.0423
# Original task: train loss: 0.1807 train accuracy: 0.9446
# [log--83%-0008399] reconstruction validation: 0.0424
# Original task: train loss: 0.1681 train accuracy: 0.9501
# [log--85%-0008599] reconstruction validation: 0.0427
# Original task: train loss: 0.1719 train accuracy: 0.9462
# [log--87%-0008799] reconstruction validation: 0.0423
# Original task: train loss: 0.1614 train accuracy: 0.9474
# [log--89%-0008999] reconstruction validation: 0.0428
# Original task: train loss: 0.1677 train accuracy: 0.9514
# [log--91%-0009199] reconstruction validation: 0.0424
# Original task: train loss: 0.1747 train accuracy: 0.9466
# [log--93%-0009399] reconstruction validation: 0.0434
# Original task: train loss: 0.1472 train accuracy: 0.9561
# [log--95%-0009599] reconstruction validation: 0.0440
# Original task: train loss: 0.1500 train accuracy: 0.9529
# [log--97%-0009799] reconstruction validation: 0.0432
# Original task: train loss: 0.1454 train accuracy: 0.9557
# [log--99%-0009999] reconstruction validation: 0.0432
# Original task: train loss: 0.1567 train accuracy: 0.9498

# %%
n = 6
fix, ax = plt.subplots(1, n, figsize=(n*5, 4))
x = np.arange(0, len(log_passive)) * log_frequency 

plot_log(ax[0], x, log_passive[:, 0],  label='tilde_f loss')
plot_log(ax[1], x, log_passive[:, 1],  label='Encoder/decoder loss')
plot_log(ax[2], x, log_passive[:, 2],  label='D loss')
plot_log(ax[3], x, log_passive[:, 3],  label='Reconstruction error')
plot_log(ax[4], x, log_passive[:, 4], label='Training loss')
# plot_log(ax[4], x, log_no_attack[:,0], color='red')
plot_log(ax[5], x, log_passive[:, 5],  label='Training accuracy')
# plot_log(ax[5], x, log_no_attack[:,1], color='red')

# %%
n = 20
X = getImagesDS(xpriv, n)
X_recovered, control = passive.attack(X)

def plot(X):
    n = len(X)
    X = (X+1)/2
    fig, ax = plt.subplots(1, n, figsize=(n*3,3))
    plt.axis('off')
    plt.subplots_adjust(wspace=0, hspace=-.05)
    for i in range(n):
        ax[i].imshow((X[i]), cmap='inferno');  
        ax[i].set(xticks=[], yticks=[])
        ax[i].set_aspect('equal')
        
    return fig

fig = plot(X)
fig = plot(X_recovered)

# %% [markdown]
# ## Save the models and outputs

# %%
active.f.save('models/decorrelation/active/f')
active.g.save('models/decorrelation/active/g')
active.decoder.save('models/decorrelation/active/decoder')
passive.f.save('models/decorrelation/passive/f')
passive.g.save('models/decorrelation/passive/g')
passive.decoder.save('models/decorrelation/passive/decoder')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/active/f\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/active/g\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/active/decoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/passive/f\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/passive/g\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/decorrelation/passive/decoder\assets

# %%
# np.savetxt('./log/log_no_attack.csv', log_no_attack, delimiter=',')
np.savetxt('./log/decorrelation/log_active.csv', log_active, delimiter=',')
np.savetxt('./log/decorrelation/log_passive.csv', log_passive, delimiter=',')

# %%
# plot the training loss:
plt.title("Original task training loss")
plt.ylabel('loss')
plt.xlabel('iteration')
plt.plot(log_passive[:,4], color='red')
plt.plot(log_active[:,4])
# plt.plot(log_no_attack[:,0], color='green')
plt.legend(['our attak', 'FSHA'], loc='upper right')
plt.show()

# %%
# plot the training accuracy:
plt.title("Original task training accuracy")
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(log_passive[:,5], color='red')
plt.plot(log_active[:,5])
# plt.plot(log_no_attack[:,1], color='green')
plt.legend(['our attak', 'FSHA'], loc='lower right')
plt.show()

# %%
# plot the reconstruction error:
plt.title("Reconstruction error")
plt.ylabel('distance')
plt.xlabel('iteration')
plt.plot(log_passive[:,3], color='red')
plt.plot(log_active[:,3])
plt.legend(['our attak', 'FSHA'], loc='upper right')
plt.show()
